# %%
import os
import sys

sys.path.append(os.getcwd())
#print(os.getenv("GITHUB_ACCESS_TOKEN", None))

from lean_dojo import *

repo = LeanGitRepo(
    #"https://github.com/leanprover-community/mathlib4",
    #"27c6744e1c0e25d676be5eb252cd4b6d30c6acc7",
    "https://github.com/leanprover-community/mathematics_in_lean",
    "210802794074c003ddf237ee56a0bf1fb5a9fe10"
)

repo
# Out:
# LeanGitRepo(url='https://github.com/leanprover-community/mathematics_in_lean', commit='210802794074c003ddf237ee56a0bf1fb5a9fe10')

# %%
# A few minutes if the traced repo is in the cache; many hours otherwise.
#traced_repo = trace(repo)

# %%
# import pickle

# fout = open('/Users/xiaoxin_yin/src/xiaoxin/axiomatization/datasets/traced_repo_math_in_lean_20240701.pkl', 'wb')
# pickle.dump(traced_repo, fout)
# fout.close()

# %%
import pickle

fin = open('/home/mcwave/code/automath/atp/datasets/traced_repo_math_in_lean_20240701.pkl', 'rb')
traced_repo = pickle.load(fin)
fin.close()

# %%
print(len(traced_repo.traced_files))

traced_file = traced_repo.get_traced_file('MIL/C02_Basics/S02_Proving_Identities_in_Algebraic_Structures.lean')

traced_file.get_premise_definitions()
# Out:
# 3143
# [{'full_name': 'MyRing.add_zero',
#   'code': 'theorem add_zero (a : R) : a + 0 = a',
#   'start': [39, 1],
#   'end': [39, 67],
#   'kind': 'commanddeclaration'},
#  {'full_name': 'MyRing.add_right_neg',
#   'code': 'theorem add_right_neg (a : R) : a + -a = 0',
#   'start': [41, 1],
#   'end': [41, 77],
#   'kind': 'commanddeclaration'},
#  {'full_name': 'MyRing.neg_add_cancel_left',
#   'code': 'theorem neg_add_cancel_left (a b : R) : -a + (a + b) = b',
#   'start': [51, 1],
#   'end': [52, 43],
#   'kind': 'commanddeclaration'},
#  {'full_name': 'MyRing.add_neg_cancel_right',
#   'code': 'theorem add_neg_cancel_right (a b : R) : a + b + -b = a',
#   'start': [55, 1],
#   'end': [56, 8],
#   'kind': 'commanddeclaration'},
#  {'full_name': 'MyRing.add_left_cancel',
#   'code': 'theorem add_left_cancel {a b c : R} (h : a + b = a + c) : b = c',
#   'start': [58, 1],
#   'end': [59, 8],
#   'kind': 'commanddeclaration'},
#  {'full_name': 'MyRing.add_right_cancel',
#   'code': 'theorem add_right_cancel {a b c : R} (h : a + b = c + b) : a = c',
#   'start': [61, 1],
#   'end': [62, 8],
#   'kind': 'commanddeclaration'},
#  {'full_name': 'MyRing.mul_zero',
#   'code': 'theorem mul_zero (a : R) : a * 0 = 0',
#   'start': [64, 1],
#   'end': [67, 25],
#   'kind': 'commanddeclaration'},
#  {'full_name': 'MyRing.zero_mul',
#   'code': 'theorem zero_mul (a : R) : 0 * a = 0',
#   'start': [69, 1],
#   'end': [70, 8],
#   'kind': 'commanddeclaration'},
#  {'full_name': 'MyRing.neg_eq_of_add_eq_zero',
#   'code': 'theorem neg_eq_of_add_eq_zero {a b : R} (h : a + b = 0) : -a = b',
#   'start': [72, 1],
#   'end': [73, 8],
#   'kind': 'commanddeclaration'},
#  {'full_name': 'MyRing.eq_neg_of_add_eq_zero',
#   'code': 'theorem eq_neg_of_add_eq_zero {a b : R} (h : a + b = 0) : a = -b',
#   'start': [75, 1],
#   'end': [76, 8],
#   'kind': 'commanddeclaration'},
#  {'full_name': 'MyRing.neg_zero',
#   'code': 'theorem neg_zero : (-0 : R) = 0',
#   'start': [78, 1],
#   'end': [80, 16],
#   'kind': 'commanddeclaration'},
#  {'full_name': 'MyRing.neg_neg',
#   'code': 'theorem neg_neg (a : R) : - -a = a',
#   'start': [82, 1],
#   'end': [83, 8],
#   'kind': 'commanddeclaration'},
#  {'full_name': 'MyRing.self_sub',
#   'code': 'theorem self_sub (a : R) : a - a = 0',
#   'start': [105, 1],
#   'end': [106, 8],
#   'kind': 'commanddeclaration'},
#  {'full_name': 'MyRing.one_add_one_eq_two',
#   'code': 'theorem one_add_one_eq_two : 1 + 1 = (2 : R)',
#   'start': [108, 1],
#   'end': [109, 11],
#   'kind': 'commanddeclaration'},
#  {'full_name': 'MyRing.two_mul',
#   'code': 'theorem two_mul (a : R) : 2 * a = a + a',
#   'start': [111, 1],
#   'end': [112, 8],
#   'kind': 'commanddeclaration'},
#  {'full_name': 'MyGroup.mul_right_inv',
#   'code': 'theorem mul_right_inv (a : G) : a * a⁻¹ = 1',
#   'start': [134, 1],
#   'end': [135, 8],
#   'kind': 'commanddeclaration'},
#  {'full_name': 'MyGroup.mul_one',
#   'code': 'theorem mul_one (a : G) : a * 1 = a',
#   'start': [137, 1],
#   'end': [138, 8],
#   'kind': 'commanddeclaration'},
#  {'full_name': 'MyGroup.mul_inv_rev',
#   'code': 'theorem mul_inv_rev (a b : G) : (a * b)⁻¹ = b⁻¹ * a⁻¹',
#   'start': [140, 1],
#   'end': [141, 8],
#   'kind': 'commanddeclaration'}]

# %%
theorem = Theorem(repo, 'MIL/C02_Basics/S02_Proving_Identities_in_Algebraic_Structures.lean', "MyRing.neg_neg") 

# For some theorems, it might take a few minutes.
dojo, state_0 = Dojo(theorem).__enter__()
print(state_0.pp)

state_1 = dojo.run_tac(state_0, "apply neg_eq_of_add_eq_zero")
print(state_1.pp)
# Out:
# 2024-08-18 13:34:56.683 | WARNING  | lean_dojo.interaction.dojo:__init__:156 - Using Lean 4 without a hard timeout may hang indefinitely.
# 2024-08-18 13:34:56.684 | INFO     | lean_dojo.interaction.dojo:__enter__:186 - Copy tree ...
# 2024-08-18 13:34:58.170 | INFO     | lean_dojo.interaction.dojo:__enter__:209 - lake build Lean4Repl ...
# 2024-08-18 13:34:58.171 | INFO     | lean_dojo.interaction.dojo:__enter__:212 - Launching the proof using <class 'lean_dojo.container.NativeContainer'>
# 2024-08-18 13:35:03.248 | INFO     | lean_dojo.interaction.dojo:__enter__:231 - run_interactive ...
# NEXTLINE: REPL> {"tacticState": "R : Type u_1\ninst✝ : Ring R\na : R\n⊢ - -a = a", "sid": 0, "error": null}
# R : Type u_1
# inst✝ : Ring R
# a : R
# ⊢ - -a = a
# NEXTLINE: REPL> {"tacticState": "case h\nR : Type u_1\ninst✝ : Ring R\na : R\n⊢ -a + a = 0", "sid": 1, "error": null}
# case h
# R : Type u_1
# inst✝ : Ring R
# a : R
# ⊢ -a + a = 0

# %%
# Example for adding equivalents

new_theorem_1_full_code = """
theorem test_theorem_1 (a b: ℝ ) : a * b + a * b = 2 * a * b := by ring
"""

new_theorem_code = "theorem test_theorem_2 (a b c: ℝ ): c * (a * b + a * b) = c * (2 * a * b) :="

theorem = Theorem(repo, 'MIL/C02_Basics/S02_Proving_Identities_in_Algebraic_Structures.lean', "test_theorem_2")

dojo, state_0 = Dojo(theorem).__enter__(new_theorem_code=new_theorem_code, supporting_theorem_code=new_theorem_1_full_code)
print(state_0.pp)
# Out:
# 2024-08-18 13:35:06.124 | WARNING  | lean_dojo.interaction.dojo:__init__:156 - Using Lean 4 without a hard timeout may hang indefinitely.
# 2024-08-18 13:35:06.125 | INFO     | lean_dojo.interaction.dojo:__enter__:186 - Copy tree ...
# 2024-08-18 13:35:07.610 | INFO     | lean_dojo.interaction.dojo:__enter__:209 - lake build Lean4Repl ...
# 2024-08-18 13:35:07.610 | INFO     | lean_dojo.interaction.dojo:__enter__:212 - Launching the proof using <class 'lean_dojo.container.NativeContainer'>
# 2024-08-18 13:35:12.633 | INFO     | lean_dojo.interaction.dojo:__enter__:231 - run_interactive ...
# NEXTLINE: REPL> {"tacticState": "a b c : ℝ\n⊢ c * (a * b + a * b) = c * (2 * a * b)", "sid": 0, "error": null}
# a b c : ℝ
# ⊢ c * (a * b + a * b) = c * (2 * a * b)

# %%
print(state_0.pp)

state_1 = dojo.run_tac(state_0, "have h1: a * b + a * b = 2 * a * b := by exact test_theorem_1 a b")
print(state_1.pp)

state_2 = dojo.run_tac(state_1, "exact congrArg (λ x => c * x) h")
print(state_2)
# Out:
# a b c : ℝ
# ⊢ c * (a * b + a * b) = c * (2 * a * b)
# NEXTLINE: REPL> {"tacticState": "a b c : ℝ\nh1 : a * b + a * b = 2 * a * b\n⊢ c * (a * b + a * b) = c * (2 * a * b)", "sid": 1, "error": null}
# a b c : ℝ
# h1 : a * b + a * b = 2 * a * b
# ⊢ c * (a * b + a * b) = c * (2 * a * b)
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "unknown identifier 'h'"}
# LeanError(error="unknown identifier 'h'")

# %%
print(state_0.pp)

state_1 = dojo.run_tac(state_0, "have h1: a * b + a * b = 2 * a * b := by exact test_theorem_1 a b")
print(state_1.pp)

state_2 = dojo.run_tac(state_1, "exact congrArg (λ x => c * x) h")
print(state_2)
# Out:
# a b c : ℝ
# ⊢ c * (a * b + a * b) = c * (2 * a * b)
# NEXTLINE: REPL> {"tacticState": "a b c : ℝ\nh1 : a * b + a * b = 2 * a * b\n⊢ c * (a * b + a * b) = c * (2 * a * b)", "sid": 2, "error": null}
# a b c : ℝ
# h1 : a * b + a * b = 2 * a * b
# ⊢ c * (a * b + a * b) = c * (2 * a * b)
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "unknown identifier 'h'"}
# LeanError(error="unknown identifier 'h'")

# %%
# Example for replacement

new_theorem_1_full_code = """
theorem test_theorem_1 (a b: ℝ ) : a * b + a * b = 2 * a * b := by ring
"""

new_theorem_code = "theorem test_theorem_2 (a b c d: ℝ ): (c + d) * b + (c + d) * b = 2 * (c + d) * b :="

theorem = Theorem(repo, 'MIL/C02_Basics/S02_Proving_Identities_in_Algebraic_Structures.lean', "test_theorem_2")

dojo, state_0 = Dojo(theorem).__enter__(new_theorem_code=new_theorem_code, supporting_theorem_code=new_theorem_1_full_code)
print(state_0.pp)
# Out:
# 2024-07-15 17:11:22.080 | WARNING  | lean_dojo.interaction.dojo:__init__:156 - Using Lean 4 without a hard timeout may hang indefinitely.
# 2024-07-15 17:11:22.082 | INFO     | lean_dojo.interaction.dojo:__enter__:186 - Copy tree ...
# 2024-07-15 17:11:23.799 | INFO     | lean_dojo.interaction.dojo:__enter__:209 - lake build Lean4Repl ...
# 2024-07-15 17:11:23.799 | INFO     | lean_dojo.interaction.dojo:__enter__:212 - Launching the proof using <class 'lean_dojo.container.NativeContainer'>
# 2024-07-15 17:11:29.535 | INFO     | lean_dojo.interaction.dojo:__enter__:231 - run_interactive ...
# NEXTLINE: REPL> {"tacticState": "a b c d : ℝ\n⊢ (c + d) * b + (c + d) * b = 2 * (c + d) * b", "sid": 0, "error": null}
# a b c d : ℝ
# ⊢ (c + d) * b + (c + d) * b = 2 * (c + d) * b

# %%
print(state_0.pp)

state_1 = dojo.run_tac(state_0, "have h1: c + d = a := by sorry")
print(state_1.pp)

state_2 = dojo.run_tac(state_1, "rw [h1]")
print(state_2.pp)

state_3 = dojo.run_tac(state_2, "exact test_theorem_1 a b")
print(state_3)

# state_2 = dojo.run_tac(state_1, "have h2: a * b + a * b = 2 * a * b := by exact test_theorem_1 a b")
# print(state_2.pp)

# state_3 = dojo.run_tac(state_1, "exact congrArg (λ x => c * x) h")
# print(state_2)
# Out:
# a b c : ℝ
# ⊢ c * (a * b + a * b) = c * (2 * a * b)
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "unknown identifier 'd'"}
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[6], line 4
#       1 print(state_0.pp)
#       3 state_1 = dojo.run_tac(state_0, "have h1: c + d = a := by sorry")
# ----> 4 print(state_1.pp)
#       6 state_2 = dojo.run_tac(state_1, "rw [h1]")
#       7 print(state_2.pp)
#
# AttributeError: 'LeanError' object has no attribute 'pp'

# %%
from utils.lean_theorem_utils import *

# Test cases
test_cases = [
    "theorem test_theorem_1 (a b: ℝ ) (h : c = b * a - d): a * b + a * b = 2 * a * b := by ring ",
    "lemma not_monotone_iff {f : ℝ → ℝ} : ¬Monotone f ↔ ∃ x y, x ≤ y ∧ f x > f y := by rw [Monotone]\n push_neg\n rfl",
    """theorem subgroup_closure {G : Type*} [Group G] (H H' : Subgroup G) : ((H ⊔ H' : Subgroup G) : Set G) = Subgroup.closure ((H : Set G) ∪ (H' : Set G)) := by
  rw [Subgroup.sup_eq_closure]
  rfl"""
]

for i, case in enumerate(test_cases, 1):
    print(f"Case {i}:")
    premise = Premise(case)
    print(premise)
    print(premise.to_theorem_code(include_tactics=True))
    print()

print("Case parse_state")
premise = Premise()
premise.parse_state("""a b c d : ℝ
h : a = c + d
⊢ b + c - (b + c) = 0""")
print(premise.to_theorem_code())
# Out:
# Case 1:
# Theorem Name: test_theorem_1
# Hypotheses: OrderedDict([('a', 'ℝ'), ('b', 'ℝ'), ('h', 'c = b * a - d')])
# Target: a * b + a * b = 2 * a * b
# Tactics: ['ring']
# theorem test_theorem_1 (a b: ℝ) (h: c = b * a - d) : a * b + a * b = 2 * a * b := by
#   ring
#
# Case 2:
# Theorem Name: not_monotone_iff
# Hypotheses: OrderedDict([('f', 'ℝ → ℝ')])
# Target: ¬Monotone f ↔ ∃ x y, x ≤ y ∧ f x > f y
# Tactics: ['rw [Monotone]', 'push_neg', 'rfl']
# theorem not_monotone_iff (f: ℝ → ℝ) : ¬Monotone f ↔ ∃ x y, x ≤ y ∧ f x > f y := by
#   rw [Monotone]
#   push_neg
#   rfl
#
# Case 3:
# Theorem Name: subgroup_closure
# Hypotheses: OrderedDict([('G', 'Type*'), ('Group', 'G'), ('H', 'Subgroup G'), ("H'", 'Subgroup G')])
# Target: ((H ⊔ H' : Subgroup G) : Set G) = Subgroup.closure ((H : Set G) ∪ (H' : Set G))
# Tactics: ['rw [Subgroup.sup_eq_closure]', 'rfl']
# theorem subgroup_closure (G: Type*) (Group: G) (H H': Subgroup G) : ((H ⊔ H' : Subgroup G) : Set G) = Subgroup.closure ((H : Set G) ∪ (H' : Set G)) := by
#   rw [Subgroup.sup_eq_closure]
#   rfl
#
# Case parse_state
# theorem  (a b c d: ℝ) (h: a = c + d) : b + c - (b + c) = 0 :=

# %%
theorem_code = "theorem test_theorem_1 (a b: ℝ ) (h : c = b * a - d): a * b + a * b = 2 * a * b := by ring "
premise = Premise(theorem_code)
get_next_variable_name(premise)
# Out:
# (['a', 'b', 'h'], 'c', 'h1')

# %%
# Test the function
targets = [
    "∀ x y, x = y → f x = f y",
    "∃ x, (f x = g x) => Prime x",
    "u ×₃ v ⬝ᵥ w ×₃ x = u ⬝ᵥ w * v ⬝ᵥ x - u ⬝ᵥ x * v ⬝ᵥ w"
]

for target in targets:
    print(tokenize(target))
# Out:
# ['∀', 'x', 'y', ',', 'x', '=', 'y', '→', 'f', 'x', '=', 'f', 'y']
# ['∃', 'x', ',', '(', 'f', 'x', '=', 'g', 'x', ')', '=>', 'Prime', 'x']
# ['u', '×₃', 'v', '⬝ᵥ', 'w', '×₃', 'x', '=', 'u', '⬝ᵥ', 'w', '*', 'v', '⬝ᵥ', 'x', '-', 'u', '⬝ᵥ', 'x', '*', 'v', '⬝ᵥ', 'w']

# %%
# Test the function
targets = [
    "∀ x y, x = y → f x = f y",
    "∃ x, (f x = g x) => Prime x",
    "u ×₃ (v ×₃ w) + v ×₃ (w ×₃ u) + w ×₃ (u ×₃ v) = 0",
    "s \ t ∪ t \ s = (s ∪ t) \ (s ∩ t)",
    "(⋃ p ∈ primes, { x | p ^ 2 ∣ x }) = { x | ∃ p ∈ primes, p ^ 2 ∣ x } ",
    "c * (a * b + a * b) = c * (2 * a * b)"
]

# for target in targets:
#     print(target)
#     tokens = tokenize(target)
#     print(tokens)
#     root = TargetNode.build_tree(tokens)
#     root.print_tree()
#     print()


expected_split_equation = [
    None,
    None,
    ('u ×₃ ( v ×₃ w ) + v ×₃ ( w ×₃ u ) + w ×₃ ( u ×₃ v )', '=', '0'),
    ('s \\ t ∪ t \\ s', '=', '( s ∪ t ) \\ ( s ∩ t )'),
    ('⋃ p ∈ primes , { x | p ^ 2 ∣ x }', '=', 'x | ∃ p ∈ primes , p ^ 2 ∣ x'),
    ('c * ( a * b + a * b )', '=', 'c * ( 2 * a * b )')
]

print("Testing split_equation")
for i in range(len(targets)):
    assert split_equation(targets[i]) == expected_split_equation[i]
print("Done")

# tokens = tokenize("c * (a * b + a * b)")
# root = TargetNode.build_tree(tokens)
# root.print_tree()
# root.get_operands(3, ['*','+'])

tokens = tokenize("c * (a * b + a * b) = c * (2 * a * b)")
root = TargetNode.build_tree(tokens)
root.print_tree()
print(root.get_operands(3, ['*','+']))
print()
print(root.get_operands(3, ['*','*']))
print()
print(root.get_operands(3, None))


tokens = tokenize("a * b + a * b = 2 * a * b")
root = TargetNode.build_tree(tokens)
root.print_tree()
print(root.get_operands(1, ['+']))
# Out:
# Testing split_equation
# Done
# =
#   *
#     c
#     +
#       *
#         a
#         b
#       *
#         a
#         b
#   *
#     c
#     *
#       *
#         2
#         a
#       b
# [('b', '(a * b)', 'c'), ('a', 'a', 'c'), ('a', 'b', 'c'), ('b', 'a', 'c'), ('c', 'a', 'a'), ('c', 'b', 'a'), ('(a * b)', '(a * b)', 'c'), ('c', '(a * b)', '(a * b)'), ('c', 'a', '(a * b)'), ('c', 'b', '(a * b)'), ('a', '(a * b)', 'c'), ('c', 'a', 'b'), ('c', 'b', 'b'), ('c', '(a * b)', 'a'), ('c', '(a * b)', 'b'), ('b', 'b', 'c'), ('(a * b)', 'a', 'c'), ('(a * b)', 'b', 'c')]
#
# [('(2 * a)', 'b', 'c'), ('c', 'b', '(2 * a)'), ('a', 'b', 'c'), ('b', 'a', 'c'), ('c', '(2 * a)', 'b'), ('c', 'b', 'a'), ('c', 'a', 'b'), ('b', '(2 * a)', 'c')]
#
# [('c', '(2 * a * b)', 'b'), ('(c * ( 2 * a * b ))', 'b', 'c'), ('(c * ( a * b + a * b ))', 'c', '(2 * a * b)'), ('a', 'c', '(c * ( 2 * a * b ))'), ('a', 'c', '(a * b + a * b)'), ('b', 'c', 'a'), ('c', 'c', 'a'), ('c', '(a * b + a * b)', 'c'), ('a', 'c', 'b'), ('b', 'b', 'c'), ('c', '(2 * a * b)', 'a'), ('b', 'c', '(2 * a * b)'), ('c', 'c', '(2 * a * b)'), ('a', '(a * b + a * b)', 'c'), ('(2 * a * b)', 'c', 'c'), ('(a * b + a * b)', 'c', '(c * ( 2 * a * b ))'), ('b', 'a', 'c'), ('c', 'a', 'c'), ('(c * ( a * b + a * b ))', '(2 * a * b)', 'c'), ('c', 'b', 'c'), ('a', 'c', 'a'), ('(2 * a * b)', 'c', '(c * ( a * b + a * b ))'), ('(a * b + a * b)', 'c', 'b'), ('c', 'a', '(c * ( a * b + a * b ))'), ('c', 'b', '(c * ( a * b + a * b ))'), ('c', '(a * b + a * b)', '(c * ( 2 * a * b ))'), ('a', 'c', '(2 * a * b)'), ('c', '(a * b + a * b)', 'b'), ('b', '(2 * a * b)', 'c'), ('b', 'c', 'c'), ('a', 'b', 'c'), ('a', 'a', 'c'), ('c', 'a', '(c * ( 2 * a * b ))'), ('(2 * a * b)', 'c', 'b'), ('(c * ( 2 * a * b ))', 'c', '(a * b + a * b)'), ('c', 'b', '(c * ( 2 * a * b ))'), ('(c * ( 2 * a * b ))', 'c', 'b'), ('(a * b + a * b)', 'c', 'a'), ('c', 'a', 'b'), ('c', 'b', 'b'), ('c', '(2 * a * b)', 'c'), ('b', 'c', '(c * ( a * b + a * b ))'), ('c', '(a * b + a * b)', 'a'), ('(c * ( a * b + a * b ))', 'c', 'b'), ('a', '(2 * a * b)', 'c'), ('a', 'c', 'c'), ('c', '(2 * a * b)', '(c * ( a * b + a * b ))'), ('(c * ( 2 * a * b ))', 'c', 'a'), ('(c * ( 2 * a * b ))', '(a * b + a * b)', 'c'), ('(2 * a * b)', 'c', 'a'), ('c', 'a', 'a'), ('(c * ( a * b + a * b ))', 'b', 'c'), ('c', 'b', 'a'), ('b', 'c', '(c * ( 2 * a * b ))'), ('b', '(a * b + a * b)', 'c'), ('c', 'c', '(a * b + a * b)'), ('c', 'c', 'b'), ('b', 'c', '(a * b + a * b)'), ('b', 'c', 'b'), ('a', 'c', '(c * ( a * b + a * b ))'), ('(c * ( a * b + a * b ))', 'c', 'a'), ('(c * ( a * b + a * b ))', 'a', 'c'), ('(c * ( 2 * a * b ))', 'a', 'c'), ('(a * b + a * b)', 'c', 'c')]
# =
#   +
#     *
#       a
#       b
#     *
#       a
#       b
#   *
#     *
#       2
#       a
#     b
# [('(a * b)',), ('a',), ('b',)]

# %%
# Each theorem in the axiom set, together with #operands, operator, and operator for reverse operation (\l)
AXIOM_METADATA = {
    'mul_add': (3, ['*','+'], ['+','*']), 
    'add_mul': (3, ['*','+'], ['+','*']),
    'mul_sub': (3, ['*','-'], ['-','*']),
    'sub_mul': (3, ['*','-'], ['-','*']),
    'mul_sub_right_distrib': (3, ['*','-'], ['-','*']),
    'two_mul': (1, ['*'], ['+']),
    'add_assoc': (3, ['+','+'], ['+','+']),
    'mul_assoc': (3, ['*','*'], ['*','*']), 
    'add_sub': (2, ['-', '+'], None), 
    'sub_sub': (2, ['-', '-'], ['-', '+']),
    'sub_sub_cancel': (2, ['-', '-'], None),
    'add_comm': (2, ['+'], None),
    'mul_comm': (2, ['*'], None),
    'add_zero': (1, ['+'], None),
    'zero_add': (1, ['+'], None),
    'mul_one': (1, ['*'], None),
    'one_mul': (1, ['*'], None),
    'mul_zero': (1, ['*'], None),
    'mul_eq_one': (2, ['*'], None),
    'one_div_mul_cancel': (1, ['*'], None),
    'mul_one_div_cancel': (1, ['*'], None),
    'mul_one_div': (2, ['*', '/'], None),
    'sub_neg_eq_add': (2, ['-'], None),
    'sub_eq_add_neg': (2, ['-'], ['+']),
    "add_right_inj": (0, None, None),
    "mul_right_inj": (0, None, None),
    "add_ne_add_right": (0, None, None),
    "mul_ne_mul_right": (0, None, None),
    "add_left_inj": (0, None, None),
    "mul_left_inj": (0, None, None),
    "add_ne_add_left": (0, None, None),
    "mul_ne_mul_left": (0, None, None),
    "comp_add_left": (0, None, None),
    "comp_mul_left": (0, None, None),
    "comp_add_right": (0, None, None),
    "comp_mul_right": (0, None, None),
    "ite_add_zero": (0, None, None),
    "ite_mul_one": (0, None, None),
    "ite_zero_add": (0, None, None),
    "ite_one_mul": (0, None, None),
    "eq_zero_iff_eq_zero_of_add_eq_zero": (0, None, None),
    "eq_one_iff_eq_one_of_mul_eq_one": (0, None, None),
    "zero_add_eq_id": (0, None, None),
    "one_mul_eq_id": (0, None, None),
    "add_zero_eq_id": (0, None, None),
    "mul_one_eq_id": (0, None, None),
    "add_left_comm": (0, None, None),
    "mul_left_comm": (0, None, None),
    "add_right_comm": (0, None, None),
    "mul_right_comm": (0, None, None),
    "add_add_add_comm": (0, None, None),
    "mul_mul_mul_comm": (0, None, None),
    "add_rotate": (0, None, None),
    "mul_rotate": (0, None, None),
    "add_rotate'": (0, None, None),
    "mul_rotate'": (0, None, None),
    "boole_nsmul": (0, None, None),
    "pow_boole": (0, None, None),
    "nsmul_add_sub_nsmul": (0, None, None),
    "pow_mul_pow_sub": (0, None, None),
    "sub_nsmul_nsmul_add": (0, None, None),
    "pow_sub_mul_pow": (0, None, None),
    "sub_one_nsmul_add": (0, None, None),
    "mul_pow_sub_one": (0, None, None),
    "add_sub_one_nsmul": (0, None, None),
    "pow_sub_one_mul": (0, None, None),
    "nsmul_eq_mod_nsmul": (0, None, None),
    "pow_eq_pow_mod": (0, None, None),
    "nsmul_add_nsmul_eq_zero.match_1": (0, None, None),
    "nsmul_add_nsmul_eq_zero": (0, None, None),
    "pow_mul_pow_eq_one": (0, None, None),
    "neg_unique": (0, None, None),
    "inv_unique": (0, None, None),
    "nsmul_add.match_1": (0, None, None),
    "nsmul_add": (0, None, None),
    "mul_pow": (0, None, None),
    "add_right_eq_self": (0, None, None),
    "mul_right_eq_self": (0, None, None),
    "self_eq_add_right": (0, None, None),
    "self_eq_mul_right": (0, None, None),
    "add_right_ne_self": (0, None, None),
    "mul_right_ne_self": (0, None, None),
    "self_ne_add_right": (0, None, None),
    "self_ne_mul_right": (0, None, None),
    "add_left_eq_self": (0, None, None),
    "mul_left_eq_self": (0, None, None),
    "self_eq_add_left": (0, None, None),
    "self_eq_mul_left": (0, None, None),
    "add_left_ne_self": (0, None, None),
    "mul_left_ne_self": (0, None, None),
    "self_ne_add_left": (0, None, None),
    "self_ne_mul_left": (0, None, None),
    "eq_iff_eq_of_add_eq_add": (0, None, None),
    "eq_iff_eq_of_mul_eq_mul": (0, None, None),
    "ne_iff_ne_of_add_eq_add": (0, None, None),
    "ne_iff_ne_of_mul_eq_mul": (0, None, None),
    "neg_inj": (0, None, None),
    "inv_inj": (0, None, None),
    "neg_eq_iff_eq_neg": (0, None, None),
    "inv_eq_iff_eq_inv": (0, None, None),
    "neg_comp_neg": (0, None, None),
    "inv_comp_inv": (0, None, None),
    "leftInverse_neg": (0, None, None),
    "leftInverse_inv": (0, None, None),
    "rightInverse_neg": (0, None, None),
    "rightInverse_inv": (0, None, None),
    "neg_eq_zero_sub": (0, None, None),
    "inv_eq_one_div": (0, None, None),
    "add_zero_sub": (0, None, None),
    "mul_one_div": (0, None, None),
    "add_sub_assoc": (0, None, None),
    "mul_div_assoc": (0, None, None),
    "add_sub_assoc'": (0, None, None),
    "mul_div_assoc'": (0, None, None),
    "zero_sub": (0, None, None),
    "one_div": (0, None, None),
    "add_sub": (0, None, None),
    "mul_div": (0, None, None),
    "sub_eq_add_zero_sub": (0, None, None),
    "div_eq_mul_one_div": (0, None, None),
    "sub_zero": (0, None, None),
    "div_one": (0, None, None),
    "zero_sub_zero": (0, None, None),
    "one_div_one": (0, None, None),
    "eq_neg_of_add_eq_zero_right": (0, None, None),
    "eq_inv_of_mul_eq_one_right": (0, None, None),
    "eq_zero_sub_of_add_eq_zero_left": (0, None, None),
    "eq_one_div_of_mul_eq_one_left": (0, None, None),
    "eq_zero_sub_of_add_eq_zero_right": (0, None, None),
    "eq_one_div_of_mul_eq_one_right": (0, None, None),
    "eq_of_sub_eq_zero": (0, None, None),
    "eq_of_div_eq_one": (0, None, None),
    "eq_of_inv_mul_eq_one": (0, None, None),
    "eq_of_mul_inv_eq_one": (0, None, None),
    "sub_ne_zero_of_ne": (0, None, None),
    "div_ne_one_of_ne": (0, None, None),
    "zero_sub_add_zero_sub_rev": (0, None, None),
    "one_div_mul_one_div_rev": (0, None, None),
    "neg_sub_left": (0, None, None),
    "inv_div_left": (0, None, None),
    "neg_sub": (0, None, None),
    "inv_div": (0, None, None),
    "zero_sub_sub": (0, None, None),
    "one_div_div": (0, None, None),
    "zero_sub_zero_sub": (0, None, None),
    "one_div_one_div": (0, None, None),
    "sub_eq_sub_iff_comm": (0, None, None),
    "div_eq_div_iff_comm": (0, None, None),
    "SubtractionMonoid.toSubNegZeroMonoid.proof_1": (0, None, None),
    "SubtractionMonoid.toSubNegZeroMonoid": (0, None, None),
    "DivisionMonoid.toDivInvOneMonoid": (0, None, None),
    "neg_nsmul": (0, None, None),
    "inv_pow": (0, None, None),
    "zsmul_zero.match_1": (0, None, None),
    "zsmul_zero": (0, None, None),
    "one_zpow": (0, None, None),
    "neg_zsmul": (0, None, None),
    "neg_zsmul.match_1": (0, None, None),
    "zpow_neg": (0, None, None),
    "neg_one_zsmul_add": (0, None, None),
    "mul_zpow_neg_one": (0, None, None),
    "zsmul_neg": (0, None, None),
    "inv_zpow": (0, None, None),
    "zsmul_neg'": (0, None, None),
    "inv_zpow'": (0, None, None),
    "nsmul_zero_sub": (0, None, None),
    "one_div_pow": (0, None, None),
    "zsmul_zero_sub": (0, None, None),
    "one_div_zpow": (0, None, None),
    "neg_eq_zero": (0, None, None),
    "inv_eq_one": (0, None, None),
    "zero_eq_neg": (0, None, None),
    "one_eq_inv": (0, None, None),
    "neg_ne_zero": (0, None, None),
    "inv_ne_one": (0, None, None),
    "eq_of_zero_sub_eq_zero_sub": (0, None, None),
    "eq_of_one_div_eq_one_div": (0, None, None),
    "mul_zsmul'": (0, None, None),
    "mul_zsmul'.match_1": (0, None, None),
    "zpow_mul": (0, None, None),
    "mul_zsmul": (0, None, None),
    "zpow_mul'": (0, None, None),
    "sub_sub_eq_add_sub": (0, None, None),
    "div_div_eq_mul_div": (0, None, None),
    "sub_neg_eq_add": (0, None, None),
    "div_inv_eq_mul": (0, None, None),
    "sub_add_eq_sub_sub_swap": (0, None, None),
    "div_mul_eq_div_div_swap": (0, None, None),
    "neg_add": (0, None, None),
    "mul_inv": (0, None, None),
    "neg_sub'": (0, None, None),
    "inv_div'": (0, None, None),
    "sub_eq_neg_add": (0, None, None),
    "div_eq_inv_mul": (0, None, None),
    "neg_add_eq_sub": (0, None, None),
    "inv_mul_eq_div": (0, None, None),
    "neg_add'": (0, None, None),
    "inv_mul'": (0, None, None),
    "neg_sub_neg": (0, None, None),
    "inv_div_inv": (0, None, None),
    "neg_neg_sub_neg": (0, None, None),
    "inv_inv_div_inv": (0, None, None),
    "zero_sub_add_zero_sub": (0, None, None),
    "one_div_mul_one_div": (0, None, None),
    "sub_right_comm": (0, None, None),
    "div_right_comm": (0, None, None),
    "sub_sub": (0, None, None),
    "div_div": (0, None, None),
    "sub_add": (0, None, None),
    "div_mul": (0, None, None),
    "add_sub_left_comm": (0, None, None),
    "mul_div_left_comm": (0, None, None),
    "add_sub_right_comm": (0, None, None),
    "mul_div_right_comm": (0, None, None),
    "sub_add_eq_sub_sub": (0, None, None),
    "div_mul_eq_div_div": (0, None, None),
    "sub_add_eq_add_sub": (0, None, None),
    "div_mul_eq_mul_div": (0, None, None),
    "zero_sub_add_eq_sub": (0, None, None),
    "one_div_mul_eq_div": (0, None, None),
    "add_comm_sub": (0, None, None),
    "mul_comm_div": (0, None, None),
    "sub_add_comm": (0, None, None),
    "div_mul_comm": (0, None, None),
    "sub_add_eq_sub_add_zero_sub": (0, None, None),
    "div_mul_eq_div_mul_one_div": (0, None, None),
    "sub_sub_sub_eq": (0, None, None),
    "div_div_div_eq": (0, None, None),
    "sub_sub_sub_comm": (0, None, None),
    "div_div_div_comm": (0, None, None),
    "sub_add_sub_comm": (0, None, None),
    "div_mul_div_comm": (0, None, None),
    "add_sub_add_comm": (0, None, None),
    "mul_div_mul_comm": (0, None, None),
    "zsmul_add": (0, None, None),
    "mul_zpow": (0, None, None),
    "nsmul_sub": (0, None, None),
    "div_pow": (0, None, None),
    "zsmul_sub": (0, None, None),
    "div_zpow": (0, None, None),
    "sub_eq_neg_self": (0, None, None),
    "div_eq_inv_self": (0, None, None),
    "eq_add_neg_of_add_eq": (0, None, None),
    "eq_mul_inv_of_mul_eq": (0, None, None),
    "eq_neg_add_of_add_eq": (0, None, None),
    "eq_inv_mul_of_mul_eq": (0, None, None),
    "neg_add_eq_of_eq_add": (0, None, None),
    "inv_mul_eq_of_eq_mul": (0, None, None),
    "add_neg_eq_of_eq_add": (0, None, None),
    "mul_inv_eq_of_eq_mul": (0, None, None),
    "eq_add_of_add_neg_eq": (0, None, None),
    "eq_mul_of_mul_inv_eq": (0, None, None),
    "eq_add_of_neg_add_eq": (0, None, None),
    "eq_mul_of_inv_mul_eq": (0, None, None),
    "add_eq_of_eq_neg_add": (0, None, None),
    "mul_eq_of_eq_inv_mul": (0, None, None),
    "add_eq_of_eq_add_neg": (0, None, None),
    "mul_eq_of_eq_mul_inv": (0, None, None),
    "add_eq_zero_iff_eq_neg": (0, None, None),
    "mul_eq_one_iff_eq_inv": (0, None, None),
    "add_eq_zero_iff_neg_eq": (0, None, None),
    "mul_eq_one_iff_inv_eq": (0, None, None),
    "eq_neg_iff_add_eq_zero": (0, None, None),
    "eq_inv_iff_mul_eq_one": (0, None, None),
    "neg_eq_iff_add_eq_zero": (0, None, None),
    "inv_eq_iff_mul_eq_one": (0, None, None),
    "eq_add_neg_iff_add_eq": (0, None, None),
    "eq_mul_inv_iff_mul_eq": (0, None, None),
    "eq_neg_add_iff_add_eq": (0, None, None),
    "eq_inv_mul_iff_mul_eq": (0, None, None),
    "neg_add_eq_iff_eq_add": (0, None, None),
    "inv_mul_eq_iff_eq_mul": (0, None, None),
    "add_neg_eq_iff_eq_add": (0, None, None),
    "mul_inv_eq_iff_eq_mul": (0, None, None),
    "add_neg_eq_zero": (0, None, None),
    "mul_inv_eq_one": (0, None, None),
    "neg_add_eq_zero": (0, None, None),
    "inv_mul_eq_one": (0, None, None),
    "conj_eq_zero_iff": (0, None, None),
    "conj_eq_one_iff": (0, None, None),
    "sub_left_injective": (0, None, None),
    "div_left_injective": (0, None, None),
    "sub_right_injective": (0, None, None),
    "div_right_injective": (0, None, None),
    "sub_add_cancel": (0, None, None),
    "div_mul_cancel": (0, None, None),
    "sub_self": (0, None, None),
    "div_self'": (0, None, None),
    "add_sub_cancel_right": (0, None, None),
    "mul_div_cancel_right": (0, None, None),
    "sub_add_cancel_right": (0, None, None),
    "div_mul_cancel_right": (0, None, None),
    "add_sub_add_right_eq_sub": (0, None, None),
    "mul_div_mul_right_eq_div": (0, None, None),
    "eq_sub_of_add_eq": (0, None, None),
    "eq_div_of_mul_eq'": (0, None, None),
    "sub_eq_of_eq_add": (0, None, None),
    "div_eq_of_eq_mul''": (0, None, None),
    "eq_add_of_sub_eq": (0, None, None),
    "eq_mul_of_div_eq": (0, None, None),
    "add_eq_of_eq_sub": (0, None, None),
    "mul_eq_of_eq_div": (0, None, None),
    "sub_right_inj": (0, None, None),
    "div_right_inj": (0, None, None),
    "sub_left_inj": (0, None, None),
    "div_left_inj": (0, None, None),
    "sub_add_sub_cancel": (0, None, None),
    "div_mul_div_cancel'": (0, None, None),
    "sub_sub_sub_cancel_right": (0, None, None),
    "div_div_div_cancel_right'": (0, None, None),
    "sub_eq_zero": (0, None, None),
    "div_eq_one": (0, None, None),
    "div_eq_one_of_eq": (0, None, None),
    "sub_eq_zero_of_eq": (0, None, None),
    "sub_ne_zero": (0, None, None),
    "div_ne_one": (0, None, None),
    "sub_eq_self": (0, None, None),
    "div_eq_self": (0, None, None),
    "eq_sub_iff_add_eq": (0, None, None),
    "eq_div_iff_mul_eq'": (0, None, None),
    "sub_eq_iff_eq_add": (0, None, None),
    "div_eq_iff_eq_mul": (0, None, None),
    "eq_iff_eq_of_sub_eq_sub": (0, None, None),
    "eq_iff_eq_of_div_eq_div": (0, None, None),
    "leftInverse_sub_add_left": (0, None, None),
    "leftInverse_div_mul_left": (0, None, None),
    "leftInverse_add_left_sub": (0, None, None),
    "leftInverse_mul_left_div": (0, None, None),
    "leftInverse_add_right_neg_add": (0, None, None),
    "leftInverse_mul_right_inv_mul": (0, None, None),
    "leftInverse_neg_add_add_right": (0, None, None),
    "leftInverse_inv_mul_mul_right": (0, None, None),
    "natAbs_nsmul_eq_zero": (0, None, None),
    "pow_natAbs_eq_one": (0, None, None),
    "exists_nsmul_eq_zero_of_zsmul_eq_zero": (0, None, None),
    "exists_pow_eq_one_of_zpow_eq_one": (0, None, None),
    "sub_nsmul": (0, None, None),
    "pow_sub": (0, None, None),
    "sub_nsmul_neg": (0, None, None),
    "inv_pow_sub": (0, None, None),
    "add_one_zsmul": (0, None, None),
    "add_one_zsmul.match_1": (0, None, None),
    "zpow_add_one": (0, None, None),
    "sub_one_zsmul": (0, None, None),
    "zpow_sub_one": (0, None, None),
    "add_zsmul": (0, None, None),
    "zpow_add": (0, None, None),
    "one_add_zsmul": (0, None, None),
    "zpow_one_add": (0, None, None),
    "add_zsmul_self": (0, None, None),
    "mul_self_zpow": (0, None, None),
    "add_self_zsmul": (0, None, None),
    "mul_zpow_self": (0, None, None),
    "sub_zsmul": (0, None, None),
    "zpow_sub": (0, None, None),
    "zsmul_add_comm": (0, None, None),
    "zpow_mul_comm": (0, None, None),
    "zpow_eq_zpow_emod": (0, None, None),
    "zpow_eq_zpow_emod'": (0, None, None),
    "zsmul_induction_left": (0, None, None),
    "zpow_induction_left": (0, None, None),
    "zsmul_induction_right": (0, None, None),
    "zpow_induction_right": (0, None, None),
    "sub_eq_of_eq_add'": (0, None, None),
    "div_eq_of_eq_mul'": (0, None, None),
    "add_sub_add_left_eq_sub": (0, None, None),
    "mul_div_mul_left_eq_div": (0, None, None),
    "eq_sub_of_add_eq'": (0, None, None),
    "eq_div_of_mul_eq''": (0, None, None),
    "eq_add_of_sub_eq'": (0, None, None),
    "eq_mul_of_div_eq'": (0, None, None),
    "add_eq_of_eq_sub'": (0, None, None),
    "mul_eq_of_eq_div'": (0, None, None),
    "sub_sub_self": (0, None, None),
    "div_div_self'": (0, None, None),
    "sub_eq_sub_add_sub": (0, None, None),
    "div_eq_div_mul_div": (0, None, None),
    "sub_sub_cancel": (0, None, None),
    "div_div_cancel": (0, None, None),
    "sub_sub_cancel_left": (0, None, None),
    "div_div_cancel_left": (0, None, None),
    "eq_sub_iff_add_eq'": (0, None, None),
    "eq_div_iff_mul_eq''": (0, None, None),
    "sub_eq_iff_eq_add'": (0, None, None),
    "div_eq_iff_eq_mul'": (0, None, None),
    "add_sub_cancel_left": (0, None, None),
    "mul_div_cancel_left": (0, None, None),
    "add_sub_cancel": (0, None, None),
    "mul_div_cancel": (0, None, None),
    "sub_add_cancel_left": (0, None, None),
    "div_mul_cancel_left": (0, None, None),
    "add_add_neg_cancel'_right": (0, None, None),
    "mul_mul_inv_cancel'_right": (0, None, None),
    "add_add_sub_cancel": (0, None, None),
    "mul_mul_div_cancel": (0, None, None),
    "sub_add_add_cancel": (0, None, None),
    "div_mul_mul_cancel": (0, None, None),
    "sub_add_sub_cancel'": (0, None, None),
    "div_mul_div_cancel''": (0, None, None),
    "add_sub_sub_cancel": (0, None, None),
    "mul_div_div_cancel": (0, None, None),
    "sub_sub_sub_cancel_left": (0, None, None),
    "div_div_div_cancel_left": (0, None, None),
    "sub_eq_sub_iff_add_eq_add": (0, None, None),
    "div_eq_div_iff_mul_eq_mul": (0, None, None),
    "sub_eq_sub_iff_sub_eq_sub": (0, None, None),
    "div_eq_div_iff_div_eq_div": (0, None, None),
    "additive_of_symmetric_of_isTotal": (0, None, None),
    "multiplicative_of_symmetric_of_isTotal": (0, None, None),
    "additive_of_isTotal": (0, None, None),
    "multiplicative_of_isTotal": (0, None, None),
    "div_mul_cancel'": (0, None, None),
    "mul_div_cancel''": (0, None, None),
    "div_mul_cancel'''": (0, None, None),
    "sub_add_cancel''": (0, None, None),
    "mul_div_cancel'''": (0, None, None),
    "add_sub_cancel'": (0, None, None),
    "mul_div_cancel'_right": (0, None, None),
    "add_sub_cancel'_right": (0, None, None),
    "div_mul_cancel''": (0, None, None),
    "sub_add_cancel'": (0, None, None)
    #'le_trans',
    #'lt_trans', 
    #'ge_trans', 
    #'gt_trans', 
}

# %%
import re
from loguru import logger

from lean_dojo.interaction.dojo import (
    LeanError,
    TimeoutError,
    TacticResult,
    DojoCrashError,
    DojoHardTimeoutError,
    DojoInitError,
    ProofGivenUp,
    ProofFinished,
)

# Returns 1 if success/giveup, 0 if normal, and -1 if error
def get_state_type(state):
    if type(state) in [LeanError,
        TimeoutError,
        TacticResult,
        DojoCrashError,
        DojoHardTimeoutError,
        DojoInitError]:
        return -1
    elif type(state) in [ProofGivenUp,ProofFinished]:
        return 1
    else:
        return 0

class PremiseSet:

    # dojo is an interactive environment of lean4, which operates on the lean4 file at full_path
    # init_state is the initial state of dojo of any premise in full_path
    def __init__(self, repo, full_path, dojo=None, init_state=None):
        self.repo = repo
        self.dojo = dojo
        self.init_state = init_state
        self.full_path = full_path
        self.premises = list()

    def get_next_theorem_name(self):
        theorem_names = [p.theorem_name for p in self.premises]
        for i in range(1000000):
            name = f"test_theorem_{i}"
            if name not in theorem_names:
                return name
        return None
        
    def add_existing_premise_by_code(self, theorem_full_code):
        premise = Premise(theorem_full_code)
        self.premises.append(premise)
        
    def add_existing_premise(self, premise):
        self.premises.append(premise)
        
    # Add equivalents - Only applicable for equation targets!
    # (e.g., "<expression> * c", where "<expression>" is each side of the equation
    # Arguments:
    #   premise: A instance of Premise
    #   equivalent: A string that is an expression like "NEW_VARIABLE * x"
    # Returns a new premise if applicable. Otherwise return None.
    #
    # It uses congr in lean4, as in this example:
    # new_theorem_1_full_code =
    # theorem test_theorem_1 (a b: ℝ ) : a * b + a * b = 2 * a * b := by
    #     ring
    # new_theorem_code = "theorem test_theorem_2 (a b c: ℝ ): c * (a * b + a * b) = c * (2 * a * b) :="
    # theorem = Theorem(repo, 'MIL/C02_Basics/S02_Proving_Identities_in_Algebraic_Structures.lean', "test_theorem_2")
    # dojo, state_0 = Dojo(theorem).__enter__(new_theorem_code=new_theorem_code, supporting_theorem_code=new_theorem_1_full_code)
    # print(state_0.pp)
    # state_1 = dojo.run_tac(state_0, "have h: a * b + a * b = 2 * a * b := by exact test_theorem_1 a b")
    # state_2 = dojo.run_tac(state_1, "exact congrArg (λ x => c * x) h")
    def add_equivalent(self, premise, equivalent, new_premise_name, var_type='ℝ'):
        print("Adding equivalent to")
        theorem_full_code = premise.to_theorem_code(include_tactics=True)
        print(theorem_full_code)
        
        # Check if premise is an equation or inequation
        split_result = split_equation(premise.target)
        if split_result is None:
            print("Not an equation or inequation")
            return None
        left, operator, right = split_result

        # Create new premise
        used_names, new_var, new_hyp = get_next_variable_name(premise)
        new_left  = equivalent.replace("NEW_VARIABLE", new_var).replace("x", f"({left})")
        new_right = equivalent.replace("NEW_VARIABLE", new_var).replace("x", f"({right})")
        new_target = new_left + " " + operator + " " + new_right
        new_premise = premise.clone()
        new_premise.theorem_name = new_premise_name
        new_premise.hypotheses[new_var] = var_type
        new_premise.target = new_target
        new_premise.tactics = [f"have {new_hyp}: {premise.target} := by exact {premise.theorem_name} {' '.join(used_names)}"]
        new_expr = equivalent.replace("NEW_VARIABLE", new_var)
        new_premise.tactics.append(f"exact congrArg (λ x => {new_expr}) {new_hyp}")
        new_theorem_code = new_premise.to_theorem_code()
        print("New Premise:")
        print(new_premise.to_theorem_code(include_tactics=True))
        
        # Test new premise and its proof using LeanDojo
        print("Entering", new_premise_name, "...")
        new_theorem = Theorem(self.repo, self.full_path, new_premise_name)
        if self.dojo is None:
            self.dojo, test_state_0 = Dojo(new_theorem, copy_tree_on_enter=False).__enter__(
                new_theorem_code=new_theorem_code, 
                supporting_theorem_code="\n" + theorem_full_code + "\n"
            )
        else:
            self.dojo.entry = new_theorem
            _, test_state_0 = self.dojo.__enter__(
                new_theorem_code=new_theorem_code, 
                supporting_theorem_code="\n" + theorem_full_code + "\n"
            )
        #print(test_state_0.pp)
        new_premise.state = test_state_0
        curr_state = test_state_0
        success = False
        for tactic in new_premise.tactics:
            next_state = self.dojo.run_tac(curr_state, tactic)
            if get_state_type(next_state) > 0:
                success = True
                break
            elif get_state_type(next_state) < 0:
                break
            else:
                curr_state = next_state

        if success:
            return new_premise
        else:
            return None

    # Replace a variable
    # (e.g., {'a' : 'c + d'}, where 'a' is in the original premise. 'c' and 'd' can be new or can be existing.
    # Arguments:
    #   premise: A instance of Premise
    #   replacement: A dict such as {'a' : '(c + d)'}
    # Returns a new premise if applicable. Otherwise return None.
    #
    # See this example:
    # new_theorem_1_full_code =
    # theorem test_theorem_1 (a b: ℝ ) : a * b + a * b = 2 * a * b := by
    #     ring
    # new_theorem_code = new_theorem_code = "theorem test_theorem_2 (a b c d: ℝ ): (c + d) * b + (c + d) * b = 2 * (c + d) * b :="
    # theorem = Theorem(repo, 'MIL/C02_Basics/S02_Proving_Identities_in_Algebraic_Structures.lean', "test_theorem_2")
    # dojo, state_0 = Dojo(theorem).__enter__(new_theorem_code=new_theorem_code, supporting_theorem_code=new_theorem_1_full_code)
    # print(state_0.pp)
    # state_1 = dojo.run_tac(state_0, "have h1: c + d = a := by sorry")
    # state_2 = dojo.run_tac(state_1, "rw [h1]")
    # state_3 = dojo.run_tac(state_2, "exact test_theorem_1 a b")
    def replace_variable(self, 
                         premise, 
                         replacement, 
                         new_premise_name,
                         apply_to_hypotheses=True,
                         var_type='ℝ'):
        print("Replace variable to")
        theorem_full_code = premise.to_theorem_code(include_tactics=True)
        print(theorem_full_code)
        
        # Get new variables
        old_variable_name = list(replacement.keys())[0]
        if old_variable_name not in premise.hypotheses:
            logger.debug(f"Variable {old_variable_name} not found")
            return None
        old_variable_type = premise.hypotheses[old_variable_name]
        new_variable_names = extract_variable_names(list(replacement.values())[0])
        
        # Create new premise
        used_names, new_var, new_hyp = get_next_variable_name(premise)
        for k, v in replacement.items():
            new_target = premise.target.replace(k, v)
        new_premise = premise.clone()
        new_premise.theorem_name = new_premise_name
        for new_var in new_variable_names:
            if new_var not in new_premise.hypotheses:
                new_premise.hypotheses[new_var] = old_variable_type
        new_premise.target = new_target
        if apply_to_hypotheses:
            hyp_names = list(new_premise.hypotheses.keys())
            for hyp_name in hyp_names:
                for k, v in replacement.items():
                    new_premise.hypotheses[hyp_name] = new_premise.hypotheses[hyp_name].replace(k, v)
            for i in range(len(new_premise.tactics)):
                for k, v in replacement.items():
                    new_premise.tactics[i] = new_premise.tactics[i].replace(k, v)
        else:
            new_premise.tactics = [
                f"have {new_hyp}: {list(replacement.values())[0]} = {list(replacement.keys())[0]} := by sorry",
                f"rw [{new_hyp}]",
                f"exact {premise.theorem_name} {' '.join(used_names)}"
            ]
        new_theorem_code = new_premise.to_theorem_code()
        print("New Premise:")
        print(new_premise.to_theorem_code(include_tactics=True))
        
        # Test new premise and its proof using LeanDojo
        print("Entering", new_premise_name, "...")
        new_theorem = Theorem(self.repo, self.full_path, new_premise_name)
        if self.dojo is None:
            self.dojo, test_state_0 = Dojo(new_theorem, copy_tree_on_enter=False).__enter__(
                new_theorem_code=new_theorem_code, 
                supporting_theorem_code="\n" + theorem_full_code + "\n"
            )
        else:
            self.dojo.entry = new_theorem
            _, test_state_0 = self.dojo.__enter__(
                new_theorem_code=new_theorem_code, 
                supporting_theorem_code="\n" + theorem_full_code + "\n"
            )
            
        #print(test_state_0.pp)
        new_premise.state = test_state_0
        curr_state = test_state_0
        success = False
        for tactic in new_premise.tactics:
            next_state = self.dojo.run_tac(curr_state, tactic)
            if get_state_type(next_state) > 0:
                success = True
                break
            elif get_state_type(next_state) < 0:
                break
            else:
                curr_state = next_state

        if success:
            return new_premise
        else:
            return None

        return new_premise

    # Try applying each axiom (and its reverse)
    # Returns a list of (tactic, premise), so that dojo can use tactic
    # to go from the input premise to the output premise.
    # Each output premise contains a member variable "state"
    def apply_axioms(self, premise, axioms, add_premises=False):
        if premise.state is None:
            theorem_full_code = premise.to_theorem_code()
            new_theorem = Theorem(repo, self.full_path, premise.theorem_name)
            #
            if self.dojo is None:
                self.dojo, state_0 = Dojo(new_theorem, copy_tree_on_enter=False).__enter__(
                    new_theorem_code=theorem_full_code
                )
            else:
                self.dojo.entry = new_theorem
                _, state_0 = ps.dojo.__enter__(
                    new_theorem_code=theorem_full_code
                )
        else:
            state_0 = premise.state
        #
        output = list()
        for tac_name, (num_operands, forward_operators, backward_operators) in axioms.items():
            # Not using operands
            tac = f"rw [{tac_name}]"
            next_state = ps.dojo.run_tac(state_0, tac)
            if get_state_type(next_state) == 0:
                premise = Premise()
                premise.theorem_name = self.get_next_theorem_name()
                premise.parse_state(next_state.pp)
                premise.state = next_state
                if add_premises:
                    self.add_existing_premise(premise)
                output.append((tac, premise))
            if num_operands <= 0:
                continue
            #
            # If operands are needed
            tokens = tokenize(premise.target)
            root = TargetNode.build_tree(tokens)
            # Forward tactic
            operands = root.get_operands(num_operands, forward_operators)
            for operand in operands:
                operand_str = ' '.join(list(operand))
                tac = f"rw [{tac_name} {operand_str}]"
                next_state = ps.dojo.run_tac(state_0, tac)
                if get_state_type(next_state) == 0:
                    premise = Premise()
                    premise.theorem_name = self.get_next_theorem_name()
                    premise.parse_state(next_state.pp)
                    premise.state = next_state
                    if add_premises:
                        self.add_existing_premise(premise)
                    output.append((tac, premise))
            # Backward tactic
            operands = root.get_operands(num_operands, backward_operators)
            for operand in operands:
                operand_str = ' '.join(list(operand))
                tac = f"rw [← {tac_name} {operand_str}]"
                next_state = ps.dojo.run_tac(state_0, tac)
                if get_state_type(next_state) == 0:
                    premise = Premise()
                    premise.theorem_name = self.get_next_theorem_name()
                    premise.parse_state(next_state.pp)
                    premise.state = next_state
                    if add_premises:
                        self.add_existing_premise(premise)
                    output.append((tac, premise))
        #
        return output
    
    # Grow a premise by applying axioms, replacements, and adding equivalents
    def grow_premise(self, premise, apply_axioms=True, add_equivalents=True, use_replacements=True):
        print("Input Premise:", premise.to_theorem_code())
        # Method 1: Apply axioms
        if apply_axioms:
            results = self.apply_axioms(premise, AXIOM_METADATA, add_premises=True)
            for (tac, new_premise) in results:
                print("TAC:", tac, "STATE:", new_premise.state.pp)
        #
        # Method 2: Add equivalents
        if add_equivalents:
            _, new_var, _ = get_next_variable_name(premise)
            equivalents = [
                f"x * {new_var}",
                f"x + {new_var}",
                f"x - {new_var}",
                f"x / {new_var}",
                f"{new_var} * x",
                f"{new_var} + x",
                f"{new_var} - x",
                f"{new_var} / x",
                f"x * x",
            ]
            for equivalent in equivalents:
                new_theorem_name = self.get_next_theorem_name()
                new_premise = self.add_equivalent(premise, equivalent, new_theorem_name)
                if new_premise is None:
                    print("Error! No premise returned")
                    continue
                self.add_existing_premise(new_premise)
                print("EQUIV:", equivalent, "THEOREM:", new_premise.to_theorem_code())
        #
        # Method 3: Replacement
        if use_replacements:
            used_names, new_var1, _ = get_next_variable_name(premise)
            _, new_var2, _ = get_next_variable_name(premise, [new_var1])
            substitutes = [
                f"({new_var1} + {new_var2})",
                f"({new_var1} - {new_var2})",
                f"({new_var1} * {new_var2})",
                f"(1 / {new_var1})",
            ]
            replacements = []
            for used_name in used_names:
                if used_name.startswith('h'):
                    continue
                substitutes.append(f"({used_name} + {new_var1})")
                substitutes.append(f"({used_name} - {new_var1})")
                substitutes.append(f"({used_name} * {new_var1})")
                substitutes.append(f"({used_name} / {new_var1})")
                for substitute in substitutes:
                    replacements.append({used_name:substitute})
            for replacement in replacements:
                new_theorem_name = self.get_next_theorem_name()
                print("REPLACEMENT:", replacement)
                new_premise = self.replace_variable(premise, replacement, new_theorem_name)
                if new_premise is None:
                    print("Error! No premise returned")
                    continue
                self.add_existing_premise(new_premise)
                print("REPLACE:", replacement, "THEOREM:", new_premise.to_theorem_code())
                
ps = PremiseSet(repo, 'MIL/C02_Basics/S02_Proving_Identities_in_Algebraic_Structures.lean', None, None)
#theorem_full_code = "theorem test_theorem_1 (a b: ℝ ) : a * b + a * b = 2 * a * b :="
theorem_full_code = """theorem test_theorem_1 (a x: ℝ ) (h: x = a) : x - a = 0 := by
  rw [h]
  ring
"""
premise = Premise(theorem_full_code)
ps.add_existing_premise(premise)
ps.grow_premise(premise, apply_axioms=True, add_equivalents=True, use_replacements=True)
# Out:
# 2024-08-17 21:46:02.816 | WARNING  | lean_dojo.interaction.dojo:__init__:156 - Using Lean 4 without a hard timeout may hang indefinitely.
# 2024-08-17 21:46:02.817 | INFO     | lean_dojo.interaction.dojo:__enter__:186 - Copy tree ...
# Input Premise: theorem test_theorem_1 (a x: ℝ) (h: x = a) : x - a = 0 :=
# 2024-08-17 21:46:04.335 | INFO     | lean_dojo.interaction.dojo:__enter__:209 - lake build Lean4Repl ...
# 2024-08-17 21:46:04.336 | INFO     | lean_dojo.interaction.dojo:__enter__:212 - Launching the proof using <class 'lean_dojo.container.NativeContainer'>
# 2024-08-17 21:46:09.366 | INFO     | lean_dojo.interaction.dojo:__enter__:231 - run_interactive ...
# NEXTLINE: REPL> {"tacticState": "a x : ℝ\nh : x = a\n⊢ x - a = 0", "sid": 0, "error": null}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  ?a * (?b + ?c)\na x : ℝ\nh : x = a\n⊢ x - a = 0"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  (?a + ?b) * ?c\na x : ℝ\nh : x = a\n⊢ x - a = 0"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  ?a * (?b - ?c)\na x : ℝ\nh : x = a\n⊢ x - a = 0"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  (?a - ?b) * ?c\na x : ℝ\nh : x = a\n⊢ x - a = 0"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  (?a - ?b) * ?c\na x : ℝ\nh : x = a\n⊢ x - a = 0"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  2 * ?n\na x : ℝ\nh : x = a\n⊢ x - a = 0"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  ?a + ?b + ?c\na x : ℝ\nh : x = a\n⊢ x - a = 0"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  ?a * ?b * ?c\na x : ℝ\nh : x = a\n⊢ x - a = 0"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  ?a + (?b - ?c)\na x : ℝ\nh : x = a\n⊢ x - a = 0"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  ?a - ?b - ?c\na x : ℝ\nh : x = a\n⊢ x - a = 0"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  ?a - (?a - ?b)\na x : ℝ\nh : x = a\n⊢ x - a = 0"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  ?a + ?b\na x : ℝ\nh : x = a\n⊢ x - a = 0"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  0 + a\na x : ℝ\nh : x = a\n⊢ x - a = 0"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  0 + x\na x : ℝ\nh : x = a\n⊢ x - a = 0"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  a + 0\na x : ℝ\nh : x = a\n⊢ x - a = 0"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  0 + (x - a)\na x : ℝ\nh : x = a\n⊢ x - a = 0"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  x + 0\na x : ℝ\nh : x = a\n⊢ x - a = 0"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  x - a + 0\na x : ℝ\nh : x = a\n⊢ x - a = 0"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  ?a * ?b\na x : ℝ\nh : x = a\n⊢ x - a = 0"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  0 * a\na x : ℝ\nh : x = a\n⊢ x - a = 0"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  0 * x\na x : ℝ\nh : x = a\n⊢ x - a = 0"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  a * 0\na x : ℝ\nh : x = a\n⊢ x - a = 0"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  0 * (x - a)\na x : ℝ\nh : x = a\n⊢ x - a = 0"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  x * 0\na x : ℝ\nh : x = a\n⊢ x - a = 0"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  (x - a) * 0\na x : ℝ\nh : x = a\n⊢ x - a = 0"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  ?a + 0\na x : ℝ\nh : x = a\n⊢ x - a = 0"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, equality or iff proof expected\n  ?m.52162\na x : ℝ\nh : x = a\n⊢ x - a = 0"}
# NEXTLINE: REPL> {"tacticState": "a x : ℝ\nh : x = a\n⊢ x - (a + 0) = 0", "sid": 1, "error": null}
# NEXTLINE: REPL> {"tacticState": "a x : ℝ\nh : x = a\n⊢ x + 0 - a = 0", "sid": 2, "error": null}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  0 + ?a\na x : ℝ\nh : x = a\n⊢ x - a = 0"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  0 + (0 - a)\na x : ℝ\nh : x = a\n⊢ x - a = 0"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  0 + x\na x : ℝ\nh : x = a\n⊢ x - a = 0"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  0 + a\na x : ℝ\nh : x = a\n⊢ x - a = 0"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, equality or iff proof expected\n  ?m.52459\na x : ℝ\nh : x = a\n⊢ x - a = 0"}
# NEXTLINE: REPL> {"tacticState": "a x : ℝ\nh : x = a\n⊢ 0 + x - a = 0", "sid": 3, "error": null}
# NEXTLINE: REPL> {"tacticState": "a x : ℝ\nh : x = a\n⊢ x - (0 + a) = 0", "sid": 4, "error": null}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  ?a * 1\na x : ℝ\nh : x = a\n⊢ x - a = 0"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, equality or iff proof expected\n  ?m.53182\na x : ℝ\nh : x = a\n⊢ x - a = 0"}
# NEXTLINE: REPL> {"tacticState": "a x : ℝ\nh : x = a\n⊢ x - a * 1 = 0", "sid": 5, "error": null}
# NEXTLINE: REPL> {"tacticState": "a x : ℝ\nh : x = a\n⊢ x * 1 - a = 0", "sid": 6, "error": null}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  1 * ?a\na x : ℝ\nh : x = a\n⊢ x - a = 0"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  1 * 1\na x : ℝ\nh : x = a\n⊢ x - a = 0"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  1 * x\na x : ℝ\nh : x = a\n⊢ x - a = 0"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, equality or iff proof expected\n  ?m.53509\na x : ℝ\nh : x = a\n⊢ x - a = 0"}
# NEXTLINE: REPL> {"tacticState": "a x : ℝ\nh : x = a\n⊢ x - 1 * a = 0", "sid": 7, "error": null}
# NEXTLINE: REPL> {"tacticState": "a x : ℝ\nh : x = a\n⊢ 1 * x - a = 0", "sid": 8, "error": null}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  ?a * 0\na x : ℝ\nh : x = a\n⊢ x - a = 0"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  1 * 0\na x : ℝ\nh : x = a\n⊢ x - a = 0"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  x * 0\na x : ℝ\nh : x = a\n⊢ x - a = 0"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, equality or iff proof expected\n  ?m.54181\na x : ℝ\nh : x = a\n⊢ x - a = 0"}
# NEXTLINE: REPL> {"tacticState": "a x : ℝ\nh : x = a\n⊢ x - a = a * 0", "sid": 9, "error": null}
# NEXTLINE: REPL> {"tacticState": "a x : ℝ\nh : x = a\n⊢ x - a = x * 0", "sid": 10, "error": null}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  ?m.54214 * ?m.54215 = 1\na x : ℝ\nh : x = a\n⊢ x - a = 0"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, equality or iff proof expected\n  ?m.54429\na x : ℝ\nh : x = a\n⊢ x - a = 0"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, equality or iff proof expected\n  ?m.54528\na x : ℝ\nh : x = a\n⊢ x - a = 0"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, equality or iff proof expected\n  ?m.54627\na x : ℝ\nh : x = a\n⊢ x - a = 0"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, equality or iff proof expected\n  ?m.54726\na x : ℝ\nh : x = a\n⊢ x - a = 0"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, equality or iff proof expected\n  ?m.54825\na x : ℝ\nh : x = a\n⊢ x - a = 0"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, equality or iff proof expected\n  ?m.54924\na x : ℝ\nh : x = a\n⊢ x - a = 0"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, equality or iff proof expected\n  ?m.55023\na x : ℝ\nh : x = a\n⊢ x - a = 0"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, equality or iff proof expected\n  ?m.55122\na x : ℝ\nh : x = a\n⊢ x - a = 0"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, equality or iff proof expected\n  ?m.55221\na x : ℝ\nh : x = a\n⊢ x - a = 0"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, equality or iff proof expected\n  ?m.55320\na x : ℝ\nh : x = a\n⊢ x - a = 0"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, equality or iff proof expected\n  ?m.55419\na x : ℝ\nh : x = a\n⊢ x - a = 0"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, equality or iff proof expected\n  ?m.55518\na x : ℝ\nh : x = a\n⊢ x - a = 0"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, equality or iff proof expected\n  ?m.55617\na x : ℝ\nh : x = a\n⊢ x - a = 0"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  1 / ?m.55622 * ?m.55622\na x : ℝ\nh : x = a\n⊢ x - a = 0"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  1 / ?m.55661 * ?m.55661\na x : ℝ\nh : x = a\n⊢ x - a = 0"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  1 / ?m.55700 * ?m.55700\na x : ℝ\nh : x = a\n⊢ x - a = 0"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  1\na x : ℝ\nh : x = a\n⊢ x - a = 0"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  1\na x : ℝ\nh : x = a\n⊢ x - a = 0"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  1\na x : ℝ\nh : x = a\n⊢ x - a = 0"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  ?m.56992 * (1 / ?m.56992)\na x : ℝ\nh : x = a\n⊢ x - a = 0"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  ?m.57031 * (1 / ?m.57031)\na x : ℝ\nh : x = a\n⊢ x - a = 0"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  ?m.57070 * (1 / ?m.57070)\na x : ℝ\nh : x = a\n⊢ x - a = 0"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  1\na x : ℝ\nh : x = a\n⊢ x - a = 0"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  1\na x : ℝ\nh : x = a\n⊢ x - a = 0"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  1\na x : ℝ\nh : x = a\n⊢ x - a = 0"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  ?x * (1 / ?y)\na x : ℝ\nh : x = a\n⊢ x - a = 0"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  ?a - -?b\na x : ℝ\nh : x = a\n⊢ x - a = 0"}
# NEXTLINE: REPL> {"tacticState": "a x : ℝ\nh : x = a\n⊢ x + -a = 0", "sid": 11, "error": null}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, equality or iff proof expected\n  ?m.58673\na x : ℝ\nh : x = a\n⊢ x - a = 0"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, equality or iff proof expected\n  ?m.59511\na x : ℝ\nh : x = a\n⊢ x - a = 0"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  ?a + ?b = ?a + ?c\na x : ℝ\nh : x = a\n⊢ x - a = 0"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  ?a * ?b = ?a * ?c\na x : ℝ\nh : x = a\n⊢ x - a = 0"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  ?a + ?b ≠ ?a + ?c\na x : ℝ\nh : x = a\n⊢ x - a = 0"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  ?a * ?b ≠ ?a * ?c\na x : ℝ\nh : x = a\n⊢ x - a = 0"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  ?b + ?a = ?c + ?a\na x : ℝ\nh : x = a\n⊢ x - a = 0"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  ?b * ?a = ?c * ?a\na x : ℝ\nh : x = a\n⊢ x - a = 0"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  ?b + ?a ≠ ?c + ?a\na x : ℝ\nh : x = a\n⊢ x - a = 0"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  ?b * ?a ≠ ?c * ?a\na x : ℝ\nh : x = a\n⊢ x - a = 0"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  (fun x => ?x + x) ∘ fun x => ?y + x\na x : ℝ\nh : x = a\n⊢ x - a = 0"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  (fun x => ?x * x) ∘ fun x => ?y * x\na x : ℝ\nh : x = a\n⊢ x - a = 0"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  (fun x => x + ?x) ∘ fun x => x + ?y\na x : ℝ\nh : x = a\n⊢ x - a = 0"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  (fun x => x * ?x) ∘ fun x => x * ?y\na x : ℝ\nh : x = a\n⊢ x - a = 0"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  if ?m.62058 then ?m.62060 + ?m.62061 else 0\na x : ℝ\nh : x = a\n⊢ x - a = 0"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  if ?m.62866 then ?m.62868 * ?m.62869 else 1\na x : ℝ\nh : x = a\n⊢ x - a = 0"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  if ?m.63643 then 0 else ?m.63645 + ?m.63646\na x : ℝ\nh : x = a\n⊢ x - a = 0"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  if ?m.64450 then 1 else ?m.64452 * ?m.64453\na x : ℝ\nh : x = a\n⊢ x - a = 0"}
# NEXTLINE: REPL> {"tacticState": "a x : ℝ\nh : x = a\n⊢ x - a + 0 = 0", "sid": 12, "error": null}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  ?m.65329 = 1\na x : ℝ\nh : x = a\n⊢ x - a = 0"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  fun x => 0 + x\na x : ℝ\nh : x = a\n⊢ x - a = 0"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  fun x => 1 * x\na x : ℝ\nh : x = a\n⊢ x - a = 0"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  fun x => x + 0\na x : ℝ\nh : x = a\n⊢ x - a = 0"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  fun x => x * 1\na x : ℝ\nh : x = a\n⊢ x - a = 0"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  ?a + (?b + ?c)\na x : ℝ\nh : x = a\n⊢ x - a = 0"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  ?a * (?b * ?c)\na x : ℝ\nh : x = a\n⊢ x - a = 0"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  ?a + ?b + ?c\na x : ℝ\nh : x = a\n⊢ x - a = 0"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  ?a * ?b * ?c\na x : ℝ\nh : x = a\n⊢ x - a = 0"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  ?a + ?b + (?c + ?d)\na x : ℝ\nh : x = a\n⊢ x - a = 0"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  ?a * ?b * (?c * ?d)\na x : ℝ\nh : x = a\n⊢ x - a = 0"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  ?a + ?b + ?c\na x : ℝ\nh : x = a\n⊢ x - a = 0"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  ?a * ?b * ?c\na x : ℝ\nh : x = a\n⊢ x - a = 0"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  ?a + (?b + ?c)\na x : ℝ\nh : x = a\n⊢ x - a = 0"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  ?a * (?b * ?c)\na x : ℝ\nh : x = a\n⊢ x - a = 0"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  (if ?P then 1 else 0) • ?a\na x : ℝ\nh : x = a\n⊢ x - a = 0"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  ?a ^ if ?P then 1 else 0\na x : ℝ\nh : x = a\n⊢ x - a = 0"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  ?m.66733 • ?a + (?m.66734 - ?m.66733) • ?a\na x : ℝ\nh : x = a\n⊢ x - a = 0"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  ?a ^ ?m.66864 * ?a ^ (?m.66865 - ?m.66864)\na x : ℝ\nh : x = a\n⊢ x - a = 0"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  (?m.67012 - ?m.67011) • ?a + ?m.67011 • ?a\na x : ℝ\nh : x = a\n⊢ x - a = 0"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  ?a ^ (?m.67143 - ?m.67142) * ?a ^ ?m.67142\na x : ℝ\nh : x = a\n⊢ x - a = 0"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  ?a + (?m.67289 - 1) • ?a\na x : ℝ\nh : x = a\n⊢ x - a = 0"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  ?a * ?a ^ (?m.67419 - 1)\na x : ℝ\nh : x = a\n⊢ x - a = 0"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  (?m.67565 - 1) • ?a + ?a\na x : ℝ\nh : x = a\n⊢ x - a = 0"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  ?a ^ (?m.67695 - 1) * ?a\na x : ℝ\nh : x = a\n⊢ x - a = 0"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  ?m • ?m.67841\na x : ℝ\nh : x = a\n⊢ x - a = 0"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  ?m.67972 ^ ?m\na x : ℝ\nh : x = a\n⊢ x - a = 0"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, equality or iff proof expected\n  ?motive ?x✝ ?x✝¹\na x : ℝ\nh : x = a\n⊢ x - a = 0"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  ?n • ?m.68270 + ?n • ?m.68271\na x : ℝ\nh : x = a\n⊢ x - a = 0"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  ?m.68401 ^ ?n * ?m.68402 ^ ?n\na x : ℝ\nh : x = a\n⊢ x - a = 0"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, pattern is a metavariable\n  ?m.68549\nfrom equation\n  ?m.68549 = ?m.68550\na x : ℝ\nh : x = a\n⊢ x - a = 0"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, pattern is a metavariable\n  ?m.68773\nfrom equation\n  ?m.68773 = ?m.68774\na x : ℝ\nh : x = a\n⊢ x - a = 0"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, equality or iff proof expected\n  ?motive ?x✝\na x : ℝ\nh : x = a\n⊢ x - a = 0"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  ?n • (?a + ?b)\na x : ℝ\nh : x = a\n⊢ x - a = 0"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  (?a * ?b) ^ ?n\na x : ℝ\nh : x = a\n⊢ x - a = 0"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  ?m.69225 + ?m.69226 = ?m.69225\na x : ℝ\nh : x = a\n⊢ x - a = 0"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  ?m.69266 * ?m.69267 = ?m.69266\na x : ℝ\nh : x = a\n⊢ x - a = 0"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  ?m.69307 = ?m.69307 + ?m.69308\na x : ℝ\nh : x = a\n⊢ x - a = 0"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  ?m.69351 = ?m.69351 * ?m.69352\na x : ℝ\nh : x = a\n⊢ x - a = 0"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  ?m.69392 + ?m.69393 ≠ ?m.69392\na x : ℝ\nh : x = a\n⊢ x - a = 0"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  ?m.69433 * ?m.69434 ≠ ?m.69433\na x : ℝ\nh : x = a\n⊢ x - a = 0"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  ?m.69474 ≠ ?m.69474 + ?m.69475\na x : ℝ\nh : x = a\n⊢ x - a = 0"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  ?m.69515 ≠ ?m.69515 * ?m.69516\na x : ℝ\nh : x = a\n⊢ x - a = 0"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  ?m.69556 + ?m.69557 = ?m.69557\na x : ℝ\nh : x = a\n⊢ x - a = 0"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  ?m.69595 * ?m.69596 = ?m.69596\na x : ℝ\nh : x = a\n⊢ x - a = 0"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  ?m.69635 = ?m.69634 + ?m.69635\na x : ℝ\nh : x = a\n⊢ x - a = 0"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  ?m.69674 = ?m.69673 * ?m.69674\na x : ℝ\nh : x = a\n⊢ x - a = 0"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  ?m.69712 + ?m.69713 ≠ ?m.69713\na x : ℝ\nh : x = a\n⊢ x - a = 0"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  ?m.69751 * ?m.69752 ≠ ?m.69752\na x : ℝ\nh : x = a\n⊢ x - a = 0"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  ?m.69791 ≠ ?m.69790 + ?m.69791\na x : ℝ\nh : x = a\n⊢ x - a = 0"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  ?m.69830 ≠ ?m.69829 * ?m.69830\na x : ℝ\nh : x = a\n⊢ x - a = 0"}
# NEXTLINE: REPL> {"tacticState": "a x : ℝ\nh : x = a\n⊢ x - a + ?m.69871 = 0 + ?m.69871\n\na x : ℝ\nh : x = a\n⊢ ℝ", "sid": 13, "error": null}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "failed to synthesize instance\n  CancelCommMonoid ℝ"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  ?m.70021 ≠ ?m.70023\na x : ℝ\nh : x = a\n⊢ x - a = 0"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  ?m.70064 ≠ ?m.70066\na x : ℝ\nh : x = a\n⊢ x - a = 0"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  -?m.70109 = -?m.70110\na x : ℝ\nh : x = a\n⊢ x - a = 0"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  ?m.70237⁻¹ = ?m.70238⁻¹\na x : ℝ\nh : x = a\n⊢ x - a = 0"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  -?m.70317 = ?m.70318\na x : ℝ\nh : x = a\n⊢ x - a = 0"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  ?m.70378⁻¹ = ?m.70379\na x : ℝ\nh : x = a\n⊢ x - a = 0"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  Neg.neg ∘ Neg.neg\na x : ℝ\nh : x = a\n⊢ x - a = 0"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  Inv.inv ∘ Inv.inv\na x : ℝ\nh : x = a\n⊢ x - a = 0"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  (fun a => -a) ((fun a => -a) ?x)\na x : ℝ\nh : x = a\n⊢ x - a = 0"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  (fun a => a⁻¹) ((fun a => a⁻¹) ?x)\na x : ℝ\nh : x = a\n⊢ x - a = 0"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  (fun a => -a) ((fun a => -a) ?x)\na x : ℝ\nh : x = a\n⊢ x - a = 0"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  (fun a => a⁻¹) ((fun a => a⁻¹) ?x)\na x : ℝ\nh : x = a\n⊢ x - a = 0"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  -?x\na x : ℝ\nh : x = a\n⊢ x - a = 0"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  ?x⁻¹\na x : ℝ\nh : x = a\n⊢ x - a = 0"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  ?x + (0 - ?y)\na x : ℝ\nh : x = a\n⊢ x - a = 0"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  ?a + ?b - ?c\na x : ℝ\nh : x = a\n⊢ x - a = 0"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  ?a * ?b / ?c\na x : ℝ\nh : x = a\n⊢ x - a = 0"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  ?a + (?b - ?c)\na x : ℝ\nh : x = a\n⊢ x - a = 0"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  ?a * (?b / ?c)\na x : ℝ\nh : x = a\n⊢ x - a = 0"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  0 - ?a\na x : ℝ\nh : x = a\n⊢ x - a = 0"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  1 / ?a\na x : ℝ\nh : x = a\n⊢ x - a = 0"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  ?a * (?b / ?c)\na x : ℝ\nh : x = a\n⊢ x - a = 0"}
# NEXTLINE: REPL> {"tacticState": "a x : ℝ\nh : x = a\n⊢ x + (0 - a) = 0", "sid": 14, "error": null}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  ?a / ?b\na x : ℝ\nh : x = a\n⊢ x - a = 0"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  ?a - 0\na x : ℝ\nh : x = a\n⊢ x - a = 0"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  ?a / 1\na x : ℝ\nh : x = a\n⊢ x - a = 0"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  0 - 0\na x : ℝ\nh : x = a\n⊢ x - a = 0"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  1 / 1\na x : ℝ\nh : x = a\n⊢ x - a = 0"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, pattern is a metavariable\n  ?m.71292\nfrom equation\n  ?m.71292 = -?m.71291\na x : ℝ\nh : x = a\n⊢ x - a = 0"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, pattern is a metavariable\n  ?m.71329\nfrom equation\n  ?m.71329 = ?m.71328⁻¹\na x : ℝ\nh : x = a\n⊢ x - a = 0"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, pattern is a metavariable\n  ?m.71372\nfrom equation\n  ?m.71372 = 0 - ?m.71371\na x : ℝ\nh : x = a\n⊢ x - a = 0"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, pattern is a metavariable\n  ?m.71409\nfrom equation\n  ?m.71409 = 1 / ?m.71408\na x : ℝ\nh : x = a\n⊢ x - a = 0"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, pattern is a metavariable\n  ?m.71452\nfrom equation\n  ?m.71452 = 0 - ?m.71451\na x : ℝ\nh : x = a\n⊢ x - a = 0"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, pattern is a metavariable\n  ?m.71489\nfrom equation\n  ?m.71489 = 1 / ?m.71488\na x : ℝ\nh : x = a\n⊢ x - a = 0"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, pattern is a metavariable\n  ?m.71531\nfrom equation\n  ?m.71531 = ?m.71532\na x : ℝ\nh : x = a\n⊢ x - a = 0"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, pattern is a metavariable\n  ?m.71568\nfrom equation\n  ?m.71568 = ?m.71569\na x : ℝ\nh : x = a\n⊢ x - a = 0"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, pattern is a metavariable\n  ?m.71611\nfrom equation\n  ?m.71611 = ?m.71612\na x : ℝ\nh : x = a\n⊢ x - a = 0"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, pattern is a metavariable\n  ?m.71654\nfrom equation\n  ?m.71654 = ?m.71655\na x : ℝ\nh : x = a\n⊢ x - a = 0"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, equality or iff proof expected\n  False\na x : ℝ\nh : x = a\n⊢ x - a = 0"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, equality or iff proof expected\n  False\na x : ℝ\nh : x = a\n⊢ x - a = 0"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  0 - ?a + (0 - ?b)\na x : ℝ\nh : x = a\n⊢ x - a = 0"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  1 / ?a * (1 / ?b)\na x : ℝ\nh : x = a\n⊢ x - a = 0"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  -?a - ?b\na x : ℝ\nh : x = a\n⊢ x - a = 0"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  ?a⁻¹ / ?b\na x : ℝ\nh : x = a\n⊢ x - a = 0"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  -(?a - ?b)\na x : ℝ\nh : x = a\n⊢ x - a = 0"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  (?a / ?b)⁻¹\na x : ℝ\nh : x = a\n⊢ x - a = 0"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  0 - (?a - ?b)\na x : ℝ\nh : x = a\n⊢ x - a = 0"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  1 / (?a / ?b)\na x : ℝ\nh : x = a\n⊢ x - a = 0"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  0 - (0 - ?a)\na x : ℝ\nh : x = a\n⊢ x - a = 0"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  1 / (1 / ?a)\na x : ℝ\nh : x = a\n⊢ x - a = 0"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  ?a - ?b = ?c - ?d\na x : ℝ\nh : x = a\n⊢ x - a = 0"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  ?a / ?b = ?c / ?d\na x : ℝ\nh : x = a\n⊢ x - a = 0"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  -0\na x : ℝ\nh : x = a\n⊢ x - a = 0"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "failed to rewrite using equation theorems for 'SubtractionMonoid.toSubNegZeroMonoid'"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "failed to rewrite using equation theorems for 'DivisionMonoid.toDivInvOneMonoid'"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  ?n • -?a\na x : ℝ\nh : x = a\n⊢ x - a = 0"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  ?a⁻¹ ^ ?n\na x : ℝ\nh : x = a\n⊢ x - a = 0"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, equality or iff proof expected\n  ?motive ?x✝\na x : ℝ\nh : x = a\n⊢ x - a = 0"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  ?n • 0\na x : ℝ\nh : x = a\n⊢ x - a = 0"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  1 ^ ?n\na x : ℝ\nh : x = a\n⊢ x - a = 0"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  -?n • ?a\na x : ℝ\nh : x = a\n⊢ x - a = 0"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, equality or iff proof expected\n  ?motive ?x✝\na x : ℝ\nh : x = a\n⊢ x - a = 0"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  ?a ^ (-?n)\na x : ℝ\nh : x = a\n⊢ x - a = 0"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  -1 • (?a + ?b)\na x : ℝ\nh : x = a\n⊢ x - a = 0"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  (?a * ?b) ^ (-1)\na x : ℝ\nh : x = a\n⊢ x - a = 0"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  ?n • -?a\na x : ℝ\nh : x = a\n⊢ x - a = 0"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  ?a⁻¹ ^ ?n\na x : ℝ\nh : x = a\n⊢ x - a = 0"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  ?n • -?a\na x : ℝ\nh : x = a\n⊢ x - a = 0"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  ?a⁻¹ ^ ?n\na x : ℝ\nh : x = a\n⊢ x - a = 0"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  ?n • (0 - ?a)\na x : ℝ\nh : x = a\n⊢ x - a = 0"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  (1 / ?a) ^ ?n\na x : ℝ\nh : x = a\n⊢ x - a = 0"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  ?n • (0 - ?a)\na x : ℝ\nh : x = a\n⊢ x - a = 0"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  (1 / ?a) ^ ?n\na x : ℝ\nh : x = a\n⊢ x - a = 0"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  -?m.73117 = 0\na x : ℝ\nh : x = a\n⊢ x - a = 0"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  ?m.73151⁻¹ = 1\na x : ℝ\nh : x = a\n⊢ x - a = 0"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  0 = -?m.73193\na x : ℝ\nh : x = a\n⊢ x - a = 0"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  1 = ?m.73227⁻¹\na x : ℝ\nh : x = a\n⊢ x - a = 0"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  -?m.73267 ≠ 0\na x : ℝ\nh : x = a\n⊢ x - a = 0"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  ?m.73301⁻¹ ≠ 1\na x : ℝ\nh : x = a\n⊢ x - a = 0"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, pattern is a metavariable\n  ?m.73341\nfrom equation\n  ?m.73341 = ?m.73342\na x : ℝ\nh : x = a\n⊢ x - a = 0"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, pattern is a metavariable\n  ?m.73378\nfrom equation\n  ?m.73378 = ?m.73379\na x : ℝ\nh : x = a\n⊢ x - a = 0"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  (?m * ?n) • ?a\na x : ℝ\nh : x = a\n⊢ x - a = 0"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, equality or iff proof expected\n  ?motive ?x✝ ?x✝¹\na x : ℝ\nh : x = a\n⊢ x - a = 0"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  ?a ^ (?m * ?n)\na x : ℝ\nh : x = a\n⊢ x - a = 0"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  (?m * ?n) • ?a\na x : ℝ\nh : x = a\n⊢ x - a = 0"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  ?a ^ (?m * ?n)\na x : ℝ\nh : x = a\n⊢ x - a = 0"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  ?a - (?b - ?c)\na x : ℝ\nh : x = a\n⊢ x - a = 0"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  ?a / (?b / ?c)\na x : ℝ\nh : x = a\n⊢ x - a = 0"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  ?a / ?b⁻¹\na x : ℝ\nh : x = a\n⊢ x - a = 0"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  ?a - (?b + ?c)\na x : ℝ\nh : x = a\n⊢ x - a = 0"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  ?a / (?b * ?c)\na x : ℝ\nh : x = a\n⊢ x - a = 0"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  -(?a + ?b)\na x : ℝ\nh : x = a\n⊢ x - a = 0"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  (?a * ?b)⁻¹\na x : ℝ\nh : x = a\n⊢ x - a = 0"}
# ...
# 2024-08-17 21:46:29.592 | INFO     | lean_dojo.interaction.dojo:_add_theorem:441 - Also copying to /tmp/tmpw8dzrn5d/mathematics_in_lean/workspace/mathematics_in_lean/MIL/C02_Basics/S02_Proving_Identities_in_Algebraic_Structures.lean
# 2024-08-17 21:46:29.592 | INFO     | lean_dojo.interaction.dojo:__enter__:231 - run_interactive ...
# NEXTLINE: REPL> {"tacticState": "a x b : ℝ\nh : x = 1 / b\n⊢ x - 1 / b = 0", "sid": 0, "error": null}
# NEXTLINE: REPL> {"tacticState": "a x b : ℝ\nh : x = 1 / b\n⊢ 1 / b - 1 / b = 0", "sid": 1, "error": null}
# NEXTLINE: REPL> {"tacticState": "no goals", "sid": 2, "error": null}
# REPLACE: {'a': '(1 / b)'} THEOREM: theorem test_theorem_36 (a x b: ℝ) (h: x = (1 / b)) : x - (1 / b) = 0 :=
# REPLACEMENT: {'a': '(a + b)'}
# Replace variable to
# theorem test_theorem_1 (a x: ℝ) (h: x = a) : x - a = 0 := by
#   rw [h]
#   ring
# New Premise:
# theorem test_theorem_37 (a x b: ℝ) (h: x = (a + b)) : x - (a + b) = 0 := by
#   rw [h]
#   ring
# Entering test_theorem_37 ...
# 2024-08-17 21:46:30.886 | INFO     | lean_dojo.interaction.dojo:_add_theorem:441 - Also copying to /tmp/tmpw8dzrn5d/mathematics_in_lean/workspace/mathematics_in_lean/MIL/C02_Basics/S02_Proving_Identities_in_Algebraic_Structures.lean
# 2024-08-17 21:46:30.886 | INFO     | lean_dojo.interaction.dojo:__enter__:231 - run_interactive ...
# NEXTLINE: REPL> {"tacticState": "a x b : ℝ\nh : x = a + b\n⊢ x - (a + b) = 0", "sid": 0, "error": null}
# NEXTLINE: REPL> {"tacticState": "a x b : ℝ\nh : x = a + b\n⊢ a + b - (a + b) = 0", "sid": 1, "error": null}
# NEXTLINE: REPL> {"tacticState": "no goals", "sid": 2, "error": null}
# REPLACE: {'a': '(a + b)'} THEOREM: theorem test_theorem_37 (a x b: ℝ) (h: x = (a + b)) : x - (a + b) = 0 :=
# REPLACEMENT: {'a': '(a - b)'}
# Replace variable to
# theorem test_theorem_1 (a x: ℝ) (h: x = a) : x - a = 0 := by
#   rw [h]
#   ring
# New Premise:
# theorem test_theorem_38 (a x b: ℝ) (h: x = (a - b)) : x - (a - b) = 0 := by
#   rw [h]
#   ring
# Entering test_theorem_38 ...
# 2024-08-17 21:46:32.211 | INFO     | lean_dojo.interaction.dojo:_add_theorem:441 - Also copying to /tmp/tmpw8dzrn5d/mathematics_in_lean/workspace/mathematics_in_lean/MIL/C02_Basics/S02_Proving_Identities_in_Algebraic_Structures.lean
# 2024-08-17 21:46:32.212 | INFO     | lean_dojo.interaction.dojo:__enter__:231 - run_interactive ...
# NEXTLINE: REPL> {"tacticState": "a x b : ℝ\nh : x = a - b\n⊢ x - (a - b) = 0", "sid": 0, "error": null}
# NEXTLINE: REPL> {"tacticState": "a x b : ℝ\nh : x = a - b\n⊢ a - b - (a - b) = 0", "sid": 1, "error": null}
# NEXTLINE: REPL> {"tacticState": "no goals", "sid": 2, "error": null}
# REPLACE: {'a': '(a - b)'} THEOREM: theorem test_theorem_38 (a x b: ℝ) (h: x = (a - b)) : x - (a - b) = 0 :=
# REPLACEMENT: {'a': '(a * b)'}
# Replace variable to
# theorem test_theorem_1 (a x: ℝ) (h: x = a) : x - a = 0 := by
#   rw [h]
#   ring
# New Premise:
# theorem test_theorem_39 (a x b: ℝ) (h: x = (a * b)) : x - (a * b) = 0 := by
#   rw [h]
#   ring
# Entering test_theorem_39 ...
# 2024-08-17 21:46:33.496 | INFO     | lean_dojo.interaction.dojo:_add_theorem:441 - Also copying to /tmp/tmpw8dzrn5d/mathematics_in_lean/workspace/mathematics_in_lean/MIL/C02_Basics/S02_Proving_Identities_in_Algebraic_Structures.lean
# 2024-08-17 21:46:33.496 | INFO     | lean_dojo.interaction.dojo:__enter__:231 - run_interactive ...
# NEXTLINE: REPL> {"tacticState": "a x b : ℝ\nh : x = a * b\n⊢ x - a * b = 0", "sid": 0, "error": null}
# NEXTLINE: REPL> {"tacticState": "a x b : ℝ\nh : x = a * b\n⊢ a * b - a * b = 0", "sid": 1, "error": null}
# NEXTLINE: REPL> {"tacticState": "no goals", "sid": 2, "error": null}
# REPLACE: {'a': '(a * b)'} THEOREM: theorem test_theorem_39 (a x b: ℝ) (h: x = (a * b)) : x - (a * b) = 0 :=
# REPLACEMENT: {'a': '(a / b)'}
# Replace variable to
# theorem test_theorem_1 (a x: ℝ) (h: x = a) : x - a = 0 := by
#   rw [h]
#   ring
# New Premise:
# theorem test_theorem_40 (a x b: ℝ) (h: x = (a / b)) : x - (a / b) = 0 := by
#   rw [h]
#   ring
# Entering test_theorem_40 ...
# 2024-08-17 21:46:34.803 | INFO     | lean_dojo.interaction.dojo:_add_theorem:441 - Also copying to /tmp/tmpw8dzrn5d/mathematics_in_lean/workspace/mathematics_in_lean/MIL/C02_Basics/S02_Proving_Identities_in_Algebraic_Structures.lean
# 2024-08-17 21:46:34.803 | INFO     | lean_dojo.interaction.dojo:__enter__:231 - run_interactive ...
# NEXTLINE: REPL> {"tacticState": "a x b : ℝ\nh : x = a / b\n⊢ x - a / b = 0", "sid": 0, "error": null}
# NEXTLINE: REPL> {"tacticState": "a x b : ℝ\nh : x = a / b\n⊢ a / b - a / b = 0", "sid": 1, "error": null}
# NEXTLINE: REPL> {"tacticState": "no goals", "sid": 2, "error": null}
# REPLACE: {'a': '(a / b)'} THEOREM: theorem test_theorem_40 (a x b: ℝ) (h: x = (a / b)) : x - (a / b) = 0 :=
# REPLACEMENT: {'x': '(b + c)'}
# Replace variable to
# theorem test_theorem_1 (a x: ℝ) (h: x = a) : x - a = 0 := by
#   rw [h]
#   ring
# New Premise:
# theorem test_theorem_41 (a x c b: ℝ) (h: (b + c) = a) : (b + c) - a = 0 := by
#   rw [h]
#   ring
# Entering test_theorem_41 ...
# 2024-08-17 21:46:36.106 | INFO     | lean_dojo.interaction.dojo:_add_theorem:441 - Also copying to /tmp/tmpw8dzrn5d/mathematics_in_lean/workspace/mathematics_in_lean/MIL/C02_Basics/S02_Proving_Identities_in_Algebraic_Structures.lean
# 2024-08-17 21:46:36.107 | INFO     | lean_dojo.interaction.dojo:__enter__:231 - run_interactive ...
# NEXTLINE: REPL> {"tacticState": "a x c b : ℝ\nh : b + c = a\n⊢ b + c - a = 0", "sid": 0, "error": null}
# NEXTLINE: REPL> {"tacticState": "a x c b : ℝ\nh : b + c = a\n⊢ a - a = 0", "sid": 1, "error": null}
# NEXTLINE: REPL> {"tacticState": "no goals", "sid": 2, "error": null}
# REPLACE: {'x': '(b + c)'} THEOREM: theorem test_theorem_41 (a x c b: ℝ) (h: (b + c) = a) : (b + c) - a = 0 :=
# REPLACEMENT: {'x': '(b - c)'}
# Replace variable to
# theorem test_theorem_1 (a x: ℝ) (h: x = a) : x - a = 0 := by
#   rw [h]
#   ring
# New Premise:
# theorem test_theorem_42 (a x c b: ℝ) (h: (b - c) = a) : (b - c) - a = 0 := by
#   rw [h]
#   ring
# Entering test_theorem_42 ...
# 2024-08-17 21:46:37.394 | INFO     | lean_dojo.interaction.dojo:_add_theorem:441 - Also copying to /tmp/tmpw8dzrn5d/mathematics_in_lean/workspace/mathematics_in_lean/MIL/C02_Basics/S02_Proving_Identities_in_Algebraic_Structures.lean
# 2024-08-17 21:46:37.394 | INFO     | lean_dojo.interaction.dojo:__enter__:231 - run_interactive ...
# NEXTLINE: REPL> {"tacticState": "a x c b : ℝ\nh : b - c = a\n⊢ b - c - a = 0", "sid": 0, "error": null}
# NEXTLINE: REPL> {"tacticState": "a x c b : ℝ\nh : b - c = a\n⊢ a - a = 0", "sid": 1, "error": null}
# NEXTLINE: REPL> {"tacticState": "no goals", "sid": 2, "error": null}
# REPLACE: {'x': '(b - c)'} THEOREM: theorem test_theorem_42 (a x c b: ℝ) (h: (b - c) = a) : (b - c) - a = 0 :=
# REPLACEMENT: {'x': '(b * c)'}
# Replace variable to
# theorem test_theorem_1 (a x: ℝ) (h: x = a) : x - a = 0 := by
#   rw [h]
#   ring
# New Premise:
# theorem test_theorem_43 (a x c b: ℝ) (h: (b * c) = a) : (b * c) - a = 0 := by
#   rw [h]
#   ring
# Entering test_theorem_43 ...
# 2024-08-17 21:46:38.733 | INFO     | lean_dojo.interaction.dojo:_add_theorem:441 - Also copying to /tmp/tmpw8dzrn5d/mathematics_in_lean/workspace/mathematics_in_lean/MIL/C02_Basics/S02_Proving_Identities_in_Algebraic_Structures.lean
# 2024-08-17 21:46:38.734 | INFO     | lean_dojo.interaction.dojo:__enter__:231 - run_interactive ...
# NEXTLINE: REPL> {"tacticState": "a x c b : ℝ\nh : b * c = a\n⊢ b * c - a = 0", "sid": 0, "error": null}
# NEXTLINE: REPL> {"tacticState": "a x c b : ℝ\nh : b * c = a\n⊢ a - a = 0", "sid": 1, "error": null}
# NEXTLINE: REPL> {"tacticState": "no goals", "sid": 2, "error": null}
# REPLACE: {'x': '(b * c)'} THEOREM: theorem test_theorem_43 (a x c b: ℝ) (h: (b * c) = a) : (b * c) - a = 0 :=
# REPLACEMENT: {'x': '(1 / b)'}
# Replace variable to
# theorem test_theorem_1 (a x: ℝ) (h: x = a) : x - a = 0 := by
#   rw [h]
#   ring
# New Premise:
# theorem test_theorem_44 (a x b: ℝ) (h: (1 / b) = a) : (1 / b) - a = 0 := by
#   rw [h]
#   ring
# Entering test_theorem_44 ...
# 2024-08-17 21:46:40.049 | INFO     | lean_dojo.interaction.dojo:_add_theorem:441 - Also copying to /tmp/tmpw8dzrn5d/mathematics_in_lean/workspace/mathematics_in_lean/MIL/C02_Basics/S02_Proving_Identities_in_Algebraic_Structures.lean
# 2024-08-17 21:46:40.051 | INFO     | lean_dojo.interaction.dojo:__enter__:231 - run_interactive ...
# NEXTLINE: REPL> {"tacticState": "a x b : ℝ\nh : 1 / b = a\n⊢ 1 / b - a = 0", "sid": 0, "error": null}
# NEXTLINE: REPL> {"tacticState": "a x b : ℝ\nh : 1 / b = a\n⊢ a - a = 0", "sid": 1, "error": null}
# NEXTLINE: REPL> {"tacticState": "no goals", "sid": 2, "error": null}
# REPLACE: {'x': '(1 / b)'} THEOREM: theorem test_theorem_44 (a x b: ℝ) (h: (1 / b) = a) : (1 / b) - a = 0 :=
# REPLACEMENT: {'x': '(a + b)'}
# Replace variable to
# theorem test_theorem_1 (a x: ℝ) (h: x = a) : x - a = 0 := by
#   rw [h]
#   ring
# New Premise:
# theorem test_theorem_45 (a x b: ℝ) (h: (a + b) = a) : (a + b) - a = 0 := by
#   rw [h]
#   ring
# Entering test_theorem_45 ...
# 2024-08-17 21:46:41.356 | INFO     | lean_dojo.interaction.dojo:_add_theorem:441 - Also copying to /tmp/tmpw8dzrn5d/mathematics_in_lean/workspace/mathematics_in_lean/MIL/C02_Basics/S02_Proving_Identities_in_Algebraic_Structures.lean
# 2024-08-17 21:46:41.356 | INFO     | lean_dojo.interaction.dojo:__enter__:231 - run_interactive ...
# NEXTLINE: REPL> {"tacticState": "a x b : ℝ\nh : a + b = a\n⊢ a + b - a = 0", "sid": 0, "error": null}
# NEXTLINE: REPL> {"tacticState": "a x b : ℝ\nh : a + b = a\n⊢ a - a = 0", "sid": 1, "error": null}
# NEXTLINE: REPL> {"tacticState": "no goals", "sid": 2, "error": null}
# REPLACE: {'x': '(a + b)'} THEOREM: theorem test_theorem_45 (a x b: ℝ) (h: (a + b) = a) : (a + b) - a = 0 :=
# REPLACEMENT: {'x': '(a - b)'}
# Replace variable to
# theorem test_theorem_1 (a x: ℝ) (h: x = a) : x - a = 0 := by
#   rw [h]
#   ring
# New Premise:
# theorem test_theorem_46 (a x b: ℝ) (h: (a - b) = a) : (a - b) - a = 0 := by
#   rw [h]
#   ring
# Entering test_theorem_46 ...
# 2024-08-17 21:46:42.629 | INFO     | lean_dojo.interaction.dojo:_add_theorem:441 - Also copying to /tmp/tmpw8dzrn5d/mathematics_in_lean/workspace/mathematics_in_lean/MIL/C02_Basics/S02_Proving_Identities_in_Algebraic_Structures.lean
# 2024-08-17 21:46:42.630 | INFO     | lean_dojo.interaction.dojo:__enter__:231 - run_interactive ...
# NEXTLINE: REPL> {"tacticState": "a x b : ℝ\nh : a - b = a\n⊢ a - b - a = 0", "sid": 0, "error": null}
# NEXTLINE: REPL> {"tacticState": "a x b : ℝ\nh : a - b = a\n⊢ a - a = 0", "sid": 1, "error": null}
# NEXTLINE: REPL> {"tacticState": "no goals", "sid": 2, "error": null}
# REPLACE: {'x': '(a - b)'} THEOREM: theorem test_theorem_46 (a x b: ℝ) (h: (a - b) = a) : (a - b) - a = 0 :=
# REPLACEMENT: {'x': '(a * b)'}
# Replace variable to
# theorem test_theorem_1 (a x: ℝ) (h: x = a) : x - a = 0 := by
#   rw [h]
#   ring
# New Premise:
# theorem test_theorem_47 (a x b: ℝ) (h: (a * b) = a) : (a * b) - a = 0 := by
#   rw [h]
#   ring
# Entering test_theorem_47 ...
# 2024-08-17 21:46:43.929 | INFO     | lean_dojo.interaction.dojo:_add_theorem:441 - Also copying to /tmp/tmpw8dzrn5d/mathematics_in_lean/workspace/mathematics_in_lean/MIL/C02_Basics/S02_Proving_Identities_in_Algebraic_Structures.lean
# 2024-08-17 21:46:43.930 | INFO     | lean_dojo.interaction.dojo:__enter__:231 - run_interactive ...
# NEXTLINE: REPL> {"tacticState": "a x b : ℝ\nh : a * b = a\n⊢ a * b - a = 0", "sid": 0, "error": null}
# NEXTLINE: REPL> {"tacticState": "a x b : ℝ\nh : a * b = a\n⊢ a - a = 0", "sid": 1, "error": null}
# NEXTLINE: REPL> {"tacticState": "no goals", "sid": 2, "error": null}
# REPLACE: {'x': '(a * b)'} THEOREM: theorem test_theorem_47 (a x b: ℝ) (h: (a * b) = a) : (a * b) - a = 0 :=
# REPLACEMENT: {'x': '(a / b)'}
# Replace variable to
# theorem test_theorem_1 (a x: ℝ) (h: x = a) : x - a = 0 := by
#   rw [h]
#   ring
# New Premise:
# theorem test_theorem_48 (a x b: ℝ) (h: (a / b) = a) : (a / b) - a = 0 := by
#   rw [h]
#   ring
# Entering test_theorem_48 ...
# 2024-08-17 21:46:45.263 | INFO     | lean_dojo.interaction.dojo:_add_theorem:441 - Also copying to /tmp/tmpw8dzrn5d/mathematics_in_lean/workspace/mathematics_in_lean/MIL/C02_Basics/S02_Proving_Identities_in_Algebraic_Structures.lean
# 2024-08-17 21:46:45.264 | INFO     | lean_dojo.interaction.dojo:__enter__:231 - run_interactive ...
# NEXTLINE: REPL> {"tacticState": "a x b : ℝ\nh : a / b = a\n⊢ a / b - a = 0", "sid": 0, "error": null}
# NEXTLINE: REPL> {"tacticState": "a x b : ℝ\nh : a / b = a\n⊢ a - a = 0", "sid": 1, "error": null}
# NEXTLINE: REPL> {"tacticState": "no goals", "sid": 2, "error": null}
# REPLACE: {'x': '(a / b)'} THEOREM: theorem test_theorem_48 (a x b: ℝ) (h: (a / b) = a) : (a / b) - a = 0 :=
# REPLACEMENT: {'x': '(x + b)'}
# Replace variable to
# theorem test_theorem_1 (a x: ℝ) (h: x = a) : x - a = 0 := by
#   rw [h]
#   ring
# New Premise:
# theorem test_theorem_49 (a x b: ℝ) (h: (x + b) = a) : (x + b) - a = 0 := by
#   rw [h]
#   ring
# Entering test_theorem_49 ...
# 2024-08-17 21:46:46.552 | INFO     | lean_dojo.interaction.dojo:_add_theorem:441 - Also copying to /tmp/tmpw8dzrn5d/mathematics_in_lean/workspace/mathematics_in_lean/MIL/C02_Basics/S02_Proving_Identities_in_Algebraic_Structures.lean
# 2024-08-17 21:46:46.553 | INFO     | lean_dojo.interaction.dojo:__enter__:231 - run_interactive ...
# NEXTLINE: REPL> {"tacticState": "a x b : ℝ\nh : x + b = a\n⊢ x + b - a = 0", "sid": 0, "error": null}
# NEXTLINE: REPL> {"tacticState": "a x b : ℝ\nh : x + b = a\n⊢ a - a = 0", "sid": 1, "error": null}
# NEXTLINE: REPL> {"tacticState": "no goals", "sid": 2, "error": null}
# REPLACE: {'x': '(x + b)'} THEOREM: theorem test_theorem_49 (a x b: ℝ) (h: (x + b) = a) : (x + b) - a = 0 :=
# REPLACEMENT: {'x': '(x - b)'}
# Replace variable to
# theorem test_theorem_1 (a x: ℝ) (h: x = a) : x - a = 0 := by
#   rw [h]
#   ring
# New Premise:
# theorem test_theorem_50 (a x b: ℝ) (h: (x - b) = a) : (x - b) - a = 0 := by
#   rw [h]
#   ring
# Entering test_theorem_50 ...
# 2024-08-17 21:46:47.826 | INFO     | lean_dojo.interaction.dojo:_add_theorem:441 - Also copying to /tmp/tmpw8dzrn5d/mathematics_in_lean/workspace/mathematics_in_lean/MIL/C02_Basics/S02_Proving_Identities_in_Algebraic_Structures.lean
# 2024-08-17 21:46:47.826 | INFO     | lean_dojo.interaction.dojo:__enter__:231 - run_interactive ...
# NEXTLINE: REPL> {"tacticState": "a x b : ℝ\nh : x - b = a\n⊢ x - b - a = 0", "sid": 0, "error": null}
# NEXTLINE: REPL> {"tacticState": "a x b : ℝ\nh : x - b = a\n⊢ a - a = 0", "sid": 1, "error": null}
# NEXTLINE: REPL> {"tacticState": "no goals", "sid": 2, "error": null}
# REPLACE: {'x': '(x - b)'} THEOREM: theorem test_theorem_50 (a x b: ℝ) (h: (x - b) = a) : (x - b) - a = 0 :=
# REPLACEMENT: {'x': '(x * b)'}
# Replace variable to
# theorem test_theorem_1 (a x: ℝ) (h: x = a) : x - a = 0 := by
#   rw [h]
#   ring
# New Premise:
# theorem test_theorem_51 (a x b: ℝ) (h: (x * b) = a) : (x * b) - a = 0 := by
#   rw [h]
#   ring
# Entering test_theorem_51 ...
# 2024-08-17 21:46:49.128 | INFO     | lean_dojo.interaction.dojo:_add_theorem:441 - Also copying to /tmp/tmpw8dzrn5d/mathematics_in_lean/workspace/mathematics_in_lean/MIL/C02_Basics/S02_Proving_Identities_in_Algebraic_Structures.lean
# 2024-08-17 21:46:49.128 | INFO     | lean_dojo.interaction.dojo:__enter__:231 - run_interactive ...
# NEXTLINE: REPL> {"tacticState": "a x b : ℝ\nh : x * b = a\n⊢ x * b - a = 0", "sid": 0, "error": null}
# NEXTLINE: REPL> {"tacticState": "a x b : ℝ\nh : x * b = a\n⊢ a - a = 0", "sid": 1, "error": null}
# NEXTLINE: REPL> {"tacticState": "no goals", "sid": 2, "error": null}
# REPLACE: {'x': '(x * b)'} THEOREM: theorem test_theorem_51 (a x b: ℝ) (h: (x * b) = a) : (x * b) - a = 0 :=
# REPLACEMENT: {'x': '(x / b)'}
# Replace variable to
# theorem test_theorem_1 (a x: ℝ) (h: x = a) : x - a = 0 := by
#   rw [h]
#   ring
# New Premise:
# theorem test_theorem_52 (a x b: ℝ) (h: (x / b) = a) : (x / b) - a = 0 := by
#   rw [h]
#   ring
# Entering test_theorem_52 ...
# NEXTLINE: REPL> {"tacticState": "a x b : ℝ\nh : x / b = a\n⊢ x / b - a = 0", "sid": 0, "error": null}
# NEXTLINE: REPL> {"tacticState": "a x b : ℝ\nh : x / b = a\n⊢ a - a = 0", "sid": 1, "error": null}
# NEXTLINE: REPL> {"tacticState": "no goals", "sid": 2, "error": null}
# REPLACE: {'x': '(x / b)'} THEOREM: theorem test_theorem_52 (a x b: ℝ) (h: (x / b) = a) : (x / b) - a = 0 :=

# %%
ps = PremiseSet(repo, 'MIL/C02_Basics/S02_Proving_Identities_in_Algebraic_Structures.lean', None, None)

# %%
theorem_full_code = "theorem test_theorem_3 (a b: ℝ ) : a * b + a * b = 2 * a * b :="
premise = Premise(theorem_full_code)
new_theorem_name = "test_theorem_2"
ps.add_existing_premise(premise)
results = ps.apply_axioms(premise, AXIOM_METADATA)
# Out:
# 2024-08-17 21:47:09.941 | WARNING  | lean_dojo.interaction.dojo:__init__:156 - Using Lean 4 without a hard timeout may hang indefinitely.
# 2024-08-17 21:47:09.943 | INFO     | lean_dojo.interaction.dojo:__enter__:186 - Copy tree ...
# 2024-08-17 21:47:11.431 | INFO     | lean_dojo.interaction.dojo:__enter__:209 - lake build Lean4Repl ...
# 2024-08-17 21:47:11.431 | INFO     | lean_dojo.interaction.dojo:__enter__:212 - Launching the proof using <class 'lean_dojo.container.NativeContainer'>
# 2024-08-17 21:47:16.504 | INFO     | lean_dojo.interaction.dojo:__enter__:231 - run_interactive ...
# NEXTLINE: REPL> {"tacticState": "a b : ℝ\n⊢ a * b + a * b = 2 * a * b", "sid": 0, "error": null}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  ?a * (?b + ?c)\na b : ℝ\n⊢ a * b + a * b = 2 * a * b"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  a * b * b + a * b * a\na b : ℝ\n⊢ a * b + a * b = 2 * a * b"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  a * b * a + a * b * b\na b : ℝ\n⊢ a * b + a * b = 2 * a * b"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  a * b + a * a\na b : ℝ\n⊢ a * b + a * b = 2 * a * b"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  a * b + a * (a * b)\na b : ℝ\n⊢ a * b + a * b = 2 * a * b"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  a * a + a * b\na b : ℝ\n⊢ a * b + a * b = 2 * a * b"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  b * a + b * a\na b : ℝ\n⊢ a * b + a * b = 2 * a * b"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  b * a + b * b\na b : ℝ\n⊢ a * b + a * b = 2 * a * b"}
# NEXTLINE: REPL> {"tacticState": "a b : ℝ\n⊢ a * (b + b) = 2 * a * b", "sid": 1, "error": null}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  b * a + b * (a * b)\na b : ℝ\n⊢ a * b + a * b = 2 * a * b"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  b * b + b * a\na b : ℝ\n⊢ a * b + a * b = 2 * a * b"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  (?a + ?b) * ?c\na b : ℝ\n⊢ a * b + a * b = 2 * a * b"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  (a + b) * b\na b : ℝ\n⊢ a * b + a * b = 2 * a * b"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  (b + b) * a\na b : ℝ\n⊢ a * b + a * b = 2 * a * b"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  ?a * (?b - ?c)\na b : ℝ\n⊢ a * b + a * b = 2 * a * b"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  (?a - ?b) * ?c\na b : ℝ\n⊢ a * b + a * b = 2 * a * b"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  (?a - ?b) * ?c\na b : ℝ\n⊢ a * b + a * b = 2 * a * b"}
# NEXTLINE: REPL> {"tacticState": "a b : ℝ\n⊢ a * b + a * b = (a + a) * b", "sid": 2, "error": null}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  2 * (a + a)\na b : ℝ\n⊢ a * b + a * b = 2 * a * b"}
# NEXTLINE: REPL> {"tacticState": "a b : ℝ\n⊢ a * b + a * b = (a + a) * b", "sid": 3, "error": null}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  2 * b\na b : ℝ\n⊢ a * b + a * b = 2 * a * b"}
# NEXTLINE: REPL> {"tacticState": "a b : ℝ\n⊢ 2 * (a * b) = 2 * a * b", "sid": 4, "error": null}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  a + a\na b : ℝ\n⊢ a * b + a * b = 2 * a * b"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  b + b\na b : ℝ\n⊢ a * b + a * b = 2 * a * b"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  ?a + ?b + ?c\na b : ℝ\n⊢ a * b + a * b = 2 * a * b"}
# NEXTLINE: REPL> {"tacticState": "a b : ℝ\n⊢ a * b + a * b = 2 * (a * b)", "sid": 5, "error": null}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  a * b * 2\na b : ℝ\n⊢ a * b + a * b = 2 * a * b"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  b * a * 2\na b : ℝ\n⊢ a * b + a * b = 2 * a * b"}
# NEXTLINE: REPL> {"tacticState": "a b : ℝ\n⊢ a * b + a * b = 2 * (a * b)", "sid": 6, "error": null}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  2 * b * a\na b : ℝ\n⊢ a * b + a * b = 2 * a * b"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  a * (b * 2)\na b : ℝ\n⊢ a * b + a * b = 2 * a * b"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  b * (a * 2)\na b : ℝ\n⊢ a * b + a * b = 2 * a * b"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  2 * (a * b)\na b : ℝ\n⊢ a * b + a * b = 2 * a * b"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  2 * (b * a)\na b : ℝ\n⊢ a * b + a * b = 2 * a * b"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  ?a + (?b - ?c)\na b : ℝ\n⊢ a * b + a * b = 2 * a * b"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  ?a - ?b - ?c\na b : ℝ\n⊢ a * b + a * b = 2 * a * b"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  ?a - (?a - ?b)\na b : ℝ\n⊢ a * b + a * b = 2 * a * b"}
# NEXTLINE: REPL> {"tacticState": "a b : ℝ\n⊢ a * b + a * b = 2 * a * b", "sid": 7, "error": null}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  a + a * b\na b : ℝ\n⊢ a * b + a * b = 2 * a * b"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  a + a\na b : ℝ\n⊢ a * b + a * b = 2 * a * b"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  a + b\na b : ℝ\n⊢ a * b + a * b = 2 * a * b"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  b + a\na b : ℝ\n⊢ a * b + a * b = 2 * a * b"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  a * b + a\na b : ℝ\n⊢ a * b + a * b = 2 * a * b"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  b + a * b\na b : ℝ\n⊢ a * b + a * b = 2 * a * b"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  b + b\na b : ℝ\n⊢ a * b + a * b = 2 * a * b"}
# NEXTLINE: REPL> {"tacticState": "a b : ℝ\n⊢ a * b + a * b = 2 * a * b", "sid": 8, "error": null}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  a * b + b\na b : ℝ\n⊢ a * b + a * b = 2 * a * b"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  a + (a * b + a * b)\na b : ℝ\n⊢ a * b + a * b = 2 * a * b"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  a + a\na b : ℝ\n⊢ a * b + a * b = 2 * a * b"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  a * b + a * b + a\na b : ℝ\n⊢ a * b + a * b = 2 * a * b"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  b + a\na b : ℝ\n⊢ a * b + a * b = 2 * a * b"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  b + 2 * a * b\na b : ℝ\n⊢ a * b + a * b = 2 * a * b"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  b + (a * b + a * b)\na b : ℝ\n⊢ a * b + a * b = 2 * a * b"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  a + b\na b : ℝ\n⊢ a * b + a * b = 2 * a * b"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  2 * a * b + a\na b : ℝ\n⊢ a * b + a * b = 2 * a * b"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  a * b + a * b + b\na b : ℝ\n⊢ a * b + a * b = 2 * a * b"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  b + b\na b : ℝ\n⊢ a * b + a * b = 2 * a * b"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  2 * a * b + (a * b + a * b)\na b : ℝ\n⊢ a * b + a * b = 2 * a * b"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  2 * a * b + b\na b : ℝ\n⊢ a * b + a * b = 2 * a * b"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  a + 2 * a * b\na b : ℝ\n⊢ a * b + a * b = 2 * a * b"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  a * b + a * b + 2 * a * b\na b : ℝ\n⊢ a * b + a * b = 2 * a * b"}
# NEXTLINE: REPL> {"tacticState": "a b : ℝ\n⊢ b * a + b * a = 2 * a * b", "sid": 9, "error": null}
# NEXTLINE: REPL> {"tacticState": "a b : ℝ\n⊢ a * b + a * b = b * (2 * a)", "sid": 10, "error": null}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  b * a\na b : ℝ\n⊢ a * b + a * b = 2 * a * b"}
# NEXTLINE: REPL> {"tacticState": "a b : ℝ\n⊢ b * a + b * a = 2 * a * b", "sid": 11, "error": null}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  b * (2 * a)\na b : ℝ\n⊢ a * b + a * b = 2 * a * b"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  b * (b * a + b * a)\na b : ℝ\n⊢ a * b + a * b = 2 * a * b"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  (b * a + b * a) * a\na b : ℝ\n⊢ a * b + a * b = 2 * a * b"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  a * a\na b : ℝ\n⊢ a * b + a * b = 2 * a * b"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  b * a\na b : ℝ\n⊢ a * b + a * b = 2 * a * b"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  b * (2 * a * b)\na b : ℝ\n⊢ a * b + a * b = 2 * a * b"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  (b * a + b * a) * b\na b : ℝ\n⊢ a * b + a * b = 2 * a * b"}
# NEXTLINE: REPL> {"tacticState": "a b : ℝ\n⊢ b * a + b * a = 2 * a * b", "sid": 12, "error": null}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  2 * a * b * (b * a + b * a)\na b : ℝ\n⊢ a * b + a * b = 2 * a * b"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  2 * a * b * a\na b : ℝ\n⊢ a * b + a * b = 2 * a * b"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  2 * a * b * b\na b : ℝ\n⊢ a * b + a * b = 2 * a * b"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  b * b\na b : ℝ\n⊢ a * b + a * b = 2 * a * b"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  a * (2 * a * b)\na b : ℝ\n⊢ a * b + a * b = 2 * a * b"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  (b * a + b * a) * (2 * a * b)\na b : ℝ\n⊢ a * b + a * b = 2 * a * b"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  a * (b * a + b * a)\na b : ℝ\n⊢ a * b + a * b = 2 * a * b"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  ?a + 0\na b : ℝ\n⊢ a * b + a * b = 2 * a * b"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  b * a + 0\na b : ℝ\n⊢ a * b + a * b = 2 * a * b"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  a + 0\na b : ℝ\n⊢ a * b + a * b = 2 * a * b"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  b + 0\na b : ℝ\n⊢ a * b + a * b = 2 * a * b"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, equality or iff proof expected\n  ?m.55500\na b : ℝ\n⊢ a * b + a * b = 2 * a * b"}
# NEXTLINE: REPL> {"tacticState": "a b : ℝ\n⊢ (a + 0) * b + (a + 0) * b = 2 * (a + 0) * b", "sid": 13, "error": null}
# NEXTLINE: REPL> {"tacticState": "a b : ℝ\n⊢ a * (b + 0) + a * (b + 0) = 2 * a * (b + 0)", "sid": 14, "error": null}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  0 + ?a\na b : ℝ\n⊢ a * b + a * b = 2 * a * b"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  0 + a * (b + 0)\na b : ℝ\n⊢ a * b + a * b = 2 * a * b"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  0 + a\na b : ℝ\n⊢ a * b + a * b = 2 * a * b"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  0 + b\na b : ℝ\n⊢ a * b + a * b = 2 * a * b"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  0 + 0\na b : ℝ\n⊢ a * b + a * b = 2 * a * b"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, equality or iff proof expected\n  ?m.56169\na b : ℝ\n⊢ a * b + a * b = 2 * a * b"}
# NEXTLINE: REPL> {"tacticState": "a b : ℝ\n⊢ (0 + a) * b + (0 + a) * b = 2 * (0 + a) * b", "sid": 15, "error": null}
# NEXTLINE: REPL> {"tacticState": "a b : ℝ\n⊢ a * (0 + b) + a * (0 + b) = 2 * a * (0 + b)", "sid": 16, "error": null}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  ?a * 1\na b : ℝ\n⊢ a * b + a * b = 2 * a * b"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  2 * a * 1\na b : ℝ\n⊢ a * b + a * b = 2 * a * b"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  a * 1\na b : ℝ\n⊢ a * b + a * b = 2 * a * b"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  b * 1\na b : ℝ\n⊢ a * b + a * b = 2 * a * b"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  (0 + b) * 1\na b : ℝ\n⊢ a * b + a * b = 2 * a * b"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, equality or iff proof expected\n  ?m.57229\na b : ℝ\n⊢ a * b + a * b = 2 * a * b"}
# NEXTLINE: REPL> {"tacticState": "a b : ℝ\n⊢ a * 1 * b + a * 1 * b = 2 * (a * 1) * b", "sid": 17, "error": null}
# NEXTLINE: REPL> {"tacticState": "a b : ℝ\n⊢ a * (b * 1) + a * (b * 1) = 2 * a * (b * 1)", "sid": 18, "error": null}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  1 * ?a\na b : ℝ\n⊢ a * b + a * b = 2 * a * b"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  1 * (2 * a)\na b : ℝ\n⊢ a * b + a * b = 2 * a * b"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  1 * (b * 1)\na b : ℝ\n⊢ a * b + a * b = 2 * a * b"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  1 * a\na b : ℝ\n⊢ a * b + a * b = 2 * a * b"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  1 * b\na b : ℝ\n⊢ a * b + a * b = 2 * a * b"}
# NEXTLINE: REPL> {"tacticState": "a b : ℝ\n⊢ a * (1 * b) + a * (1 * b) = 2 * a * (1 * b)", "sid": 19, "error": null}
# NEXTLINE: REPL> {"tacticState": "a b : ℝ\n⊢ 1 * a * b + 1 * a * b = 2 * (1 * a) * b", "sid": 20, "error": null}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, equality or iff proof expected\n  ?m.57789\na b : ℝ\n⊢ a * b + a * b = 2 * a * b"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  ?a * 0\na b : ℝ\n⊢ a * b + a * b = 2 * a * b"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  2 * (1 * a) * 0\na b : ℝ\n⊢ a * b + a * b = 2 * a * b"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  a * 0\na b : ℝ\n⊢ a * b + a * b = 2 * a * b"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  b * 0\na b : ℝ\n⊢ a * b + a * b = 2 * a * b"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  1 * a * 0\na b : ℝ\n⊢ a * b + a * b = 2 * a * b"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  0\na b : ℝ\n⊢ a * b + a * b = 2 * a * b"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, equality or iff proof expected\n  ?m.58747\na b : ℝ\n⊢ a * b + a * b = 2 * a * b"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  0\na b : ℝ\n⊢ a * b + a * b = 2 * a * b"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  ?m.58756 * ?m.58757 = 1\na b : ℝ\n⊢ a * b + a * b = 2 * a * b"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, equality or iff proof expected\n  ?m.58967\na b : ℝ\n⊢ a * b + a * b = 2 * a * b"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, equality or iff proof expected\n  ?m.59066\na b : ℝ\n⊢ a * b + a * b = 2 * a * b"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, equality or iff proof expected\n  ?m.59165\na b : ℝ\n⊢ a * b + a * b = 2 * a * b"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, equality or iff proof expected\n  ?m.59264\na b : ℝ\n⊢ a * b + a * b = 2 * a * b"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, equality or iff proof expected\n  ?m.59363\na b : ℝ\n⊢ a * b + a * b = 2 * a * b"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, equality or iff proof expected\n  ?m.59462\na b : ℝ\n⊢ a * b + a * b = 2 * a * b"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, equality or iff proof expected\n  ?m.59561\na b : ℝ\n⊢ a * b + a * b = 2 * a * b"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, equality or iff proof expected\n  ?m.59660\na b : ℝ\n⊢ a * b + a * b = 2 * a * b"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, equality or iff proof expected\n  ?m.59759\na b : ℝ\n⊢ a * b + a * b = 2 * a * b"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, equality or iff proof expected\n  ?m.59858\na b : ℝ\n⊢ a * b + a * b = 2 * a * b"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, equality or iff proof expected\n  ?m.59957\na b : ℝ\n⊢ a * b + a * b = 2 * a * b"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, equality or iff proof expected\n  ?m.60056\na b : ℝ\n⊢ a * b + a * b = 2 * a * b"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, equality or iff proof expected\n  ?m.60155\na b : ℝ\n⊢ a * b + a * b = 2 * a * b"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, equality or iff proof expected\n  ?m.60254\na b : ℝ\n⊢ a * b + a * b = 2 * a * b"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, equality or iff proof expected\n  ?m.60353\na b : ℝ\n⊢ a * b + a * b = 2 * a * b"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, equality or iff proof expected\n  ?m.60452\na b : ℝ\n⊢ a * b + a * b = 2 * a * b"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, equality or iff proof expected\n  ?m.60551\na b : ℝ\n⊢ a * b + a * b = 2 * a * b"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, equality or iff proof expected\n  ?m.60650\na b : ℝ\n⊢ a * b + a * b = 2 * a * b"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, equality or iff proof expected\n  ?m.60749\na b : ℝ\n⊢ a * b + a * b = 2 * a * b"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, equality or iff proof expected\n  ?m.60848\na b : ℝ\n⊢ a * b + a * b = 2 * a * b"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  1 / ?m.60853 * ?m.60853\na b : ℝ\n⊢ a * b + a * b = 2 * a * b"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  1 / ?m.60913 * ?m.60913\na b : ℝ\n⊢ a * b + a * b = 2 * a * b"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  1 / ?m.61915 * ?m.61915\na b : ℝ\n⊢ a * b + a * b = 2 * a * b"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  1 / ?m.62228 * ?m.62228\na b : ℝ\n⊢ a * b + a * b = 2 * a * b"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  1 / ?m.62541 * ?m.62541\na b : ℝ\n⊢ a * b + a * b = 2 * a * b"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  1\na b : ℝ\n⊢ a * b + a * b = 2 * a * b"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  1\na b : ℝ\n⊢ a * b + a * b = 2 * a * b"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  1\na b : ℝ\n⊢ a * b + a * b = 2 * a * b"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  ?m.64656 * (1 / ?m.64656)\na b : ℝ\n⊢ a * b + a * b = 2 * a * b"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  ?m.64701 * (1 / ?m.64701)\na b : ℝ\n⊢ a * b + a * b = 2 * a * b"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  ?m.65645 * (1 / ?m.65645)\na b : ℝ\n⊢ a * b + a * b = 2 * a * b"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  ?m.65949 * (1 / ?m.65949)\na b : ℝ\n⊢ a * b + a * b = 2 * a * b"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  ?m.66253 * (1 / ?m.66253)\na b : ℝ\n⊢ a * b + a * b = 2 * a * b"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  1\na b : ℝ\n⊢ a * b + a * b = 2 * a * b"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  1\na b : ℝ\n⊢ a * b + a * b = 2 * a * b"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  1\na b : ℝ\n⊢ a * b + a * b = 2 * a * b"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  ?x * (1 / ?y)\na b : ℝ\n⊢ a * b + a * b = 2 * a * b"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  ?a - -?b\na b : ℝ\n⊢ a * b + a * b = 2 * a * b"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  ?a - ?b\na b : ℝ\n⊢ a * b + a * b = 2 * a * b"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  a + -a\na b : ℝ\n⊢ a * b + a * b = 2 * a * b"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  a + -b\na b : ℝ\n⊢ a * b + a * b = 2 * a * b"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  b + -(1 * a * b)\na b : ℝ\n⊢ a * b + a * b = 2 * a * b"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  1 * a * b + -(1 * a * b)\na b : ℝ\n⊢ a * b + a * b = 2 * a * b"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  b + -a\na b : ℝ\n⊢ a * b + a * b = 2 * a * b"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  a + -(1 * a * b)\na b : ℝ\n⊢ a * b + a * b = 2 * a * b"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  1 * a * b + -a\na b : ℝ\n⊢ a * b + a * b = 2 * a * b"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  1 * a * b + -b\na b : ℝ\n⊢ a * b + a * b = 2 * a * b"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  b + -b\na b : ℝ\n⊢ a * b + a * b = 2 * a * b"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  ?a + ?b = ?a + ?c\na b : ℝ\n⊢ a * b + a * b = 2 * a * b"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  ?a * ?b = ?a * ?c\na b : ℝ\n⊢ a * b + a * b = 2 * a * b"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  ?a + ?b ≠ ?a + ?c\na b : ℝ\n⊢ a * b + a * b = 2 * a * b"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  ?a * ?b ≠ ?a * ?c\na b : ℝ\n⊢ a * b + a * b = 2 * a * b"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  ?b + ?a = ?c + ?a\na b : ℝ\n⊢ a * b + a * b = 2 * a * b"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  ?b * ?a = ?c * ?a\na b : ℝ\n⊢ a * b + a * b = 2 * a * b"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  ?b + ?a ≠ ?c + ?a\na b : ℝ\n⊢ a * b + a * b = 2 * a * b"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  ?b * ?a ≠ ?c * ?a\na b : ℝ\n⊢ a * b + a * b = 2 * a * b"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  (fun x => ?x + x) ∘ fun x => ?y + x\na b : ℝ\n⊢ a * b + a * b = 2 * a * b"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  (fun x => ?x * x) ∘ fun x => ?y * x\na b : ℝ\n⊢ a * b + a * b = 2 * a * b"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  (fun x => x + ?x) ∘ fun x => x + ?y\na b : ℝ\n⊢ a * b + a * b = 2 * a * b"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  (fun x => x * ?x) ∘ fun x => x * ?y\na b : ℝ\n⊢ a * b + a * b = 2 * a * b"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  if ?m.71544 then ?m.71546 + ?m.71547 else 0\na b : ℝ\n⊢ a * b + a * b = 2 * a * b"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  if ?m.72352 then ?m.72354 * ?m.72355 else 1\na b : ℝ\n⊢ a * b + a * b = 2 * a * b"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  if ?m.73129 then 0 else ?m.73131 + ?m.73132\na b : ℝ\n⊢ a * b + a * b = 2 * a * b"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  if ?m.73936 then 1 else ?m.73938 * ?m.73939\na b : ℝ\n⊢ a * b + a * b = 2 * a * b"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  ?m.74713 = 0\na b : ℝ\n⊢ a * b + a * b = 2 * a * b"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  ?m.74808 = 1\na b : ℝ\n⊢ a * b + a * b = 2 * a * b"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  fun x => 0 + x\na b : ℝ\n⊢ a * b + a * b = 2 * a * b"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  fun x => 1 * x\na b : ℝ\n⊢ a * b + a * b = 2 * a * b"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  fun x => x + 0\na b : ℝ\n⊢ a * b + a * b = 2 * a * b"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  fun x => x * 1\na b : ℝ\n⊢ a * b + a * b = 2 * a * b"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  ?a + (?b + ?c)\na b : ℝ\n⊢ a * b + a * b = 2 * a * b"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  ?a * (?b * ?c)\na b : ℝ\n⊢ a * b + a * b = 2 * a * b"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  ?a + ?b + ?c\na b : ℝ\n⊢ a * b + a * b = 2 * a * b"}
# NEXTLINE: REPL> {"tacticState": "a b : ℝ\n⊢ a * b + a * b = 2 * b * a", "sid": 21, "error": null}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  ?a + ?b + (?c + ?d)\na b : ℝ\n⊢ a * b + a * b = 2 * a * b"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  ?a * ?b * (?c * ?d)\na b : ℝ\n⊢ a * b + a * b = 2 * a * b"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  ?a + ?b + ?c\na b : ℝ\n⊢ a * b + a * b = 2 * a * b"}
# NEXTLINE: REPL> {"tacticState": "a b : ℝ\n⊢ a * b + a * b = a * b * 2", "sid": 22, "error": null}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  ?a + (?b + ?c)\na b : ℝ\n⊢ a * b + a * b = 2 * a * b"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  ?a * (?b * ?c)\na b : ℝ\n⊢ a * b + a * b = 2 * a * b"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  (if ?P then 1 else 0) • ?a\na b : ℝ\n⊢ a * b + a * b = 2 * a * b"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  ?a ^ if ?P then 1 else 0\na b : ℝ\n⊢ a * b + a * b = 2 * a * b"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  ?m.76313 • ?a + (?m.76314 - ?m.76313) • ?a\na b : ℝ\n⊢ a * b + a * b = 2 * a * b"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  ?a ^ ?m.76464 * ?a ^ (?m.76465 - ?m.76464)\na b : ℝ\n⊢ a * b + a * b = 2 * a * b"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  (?m.76630 - ?m.76629) • ?a + ?m.76629 • ?a\na b : ℝ\n⊢ a * b + a * b = 2 * a * b"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  ?a ^ (?m.76775 - ?m.76774) * ?a ^ ?m.76774\na b : ℝ\n⊢ a * b + a * b = 2 * a * b"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  ?a + (?m.76933 - 1) • ?a\na b : ℝ\n⊢ a * b + a * b = 2 * a * b"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  ?a * ?a ^ (?m.77071 - 1)\na b : ℝ\n⊢ a * b + a * b = 2 * a * b"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  (?m.77223 - 1) • ?a + ?a\na b : ℝ\n⊢ a * b + a * b = 2 * a * b"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  ?a ^ (?m.77367 - 1) * ?a\na b : ℝ\n⊢ a * b + a * b = 2 * a * b"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  ?m • ?m.77525\na b : ℝ\n⊢ a * b + a * b = 2 * a * b"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  ?m.77656 ^ ?m\na b : ℝ\n⊢ a * b + a * b = 2 * a * b"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, equality or iff proof expected\n  ?motive ?x✝ ?x✝¹\na b : ℝ\n⊢ a * b + a * b = 2 * a * b"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  ?n • ?m.77954 + ?n • ?m.77955\na b : ℝ\n⊢ a * b + a * b = 2 * a * b"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  ?m.78099 ^ ?n * ?m.78100 ^ ?n\na b : ℝ\n⊢ a * b + a * b = 2 * a * b"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, pattern is a metavariable\n  ?m.78259\nfrom equation\n  ?m.78259 = ?m.78260\na b : ℝ\n⊢ a * b + a * b = 2 * a * b"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, pattern is a metavariable\n  ?m.78483\nfrom equation\n  ?m.78483 = ?m.78484\na b : ℝ\n⊢ a * b + a * b = 2 * a * b"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, equality or iff proof expected\n  ?motive ?x✝\na b : ℝ\n⊢ a * b + a * b = 2 * a * b"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  ?n • (?a + ?b)\na b : ℝ\n⊢ a * b + a * b = 2 * a * b"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  (?a * ?b) ^ ?n\na b : ℝ\n⊢ a * b + a * b = 2 * a * b"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  ?m.78935 + ?m.78936 = ?m.78935\na b : ℝ\n⊢ a * b + a * b = 2 * a * b"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  ?m.78999 * ?m.79000 = ?m.78999\na b : ℝ\n⊢ a * b + a * b = 2 * a * b"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  ?m.79042 = ?m.79042 + ?m.79043\na b : ℝ\n⊢ a * b + a * b = 2 * a * b"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  ?m.79083 = ?m.79083 * ?m.79084\na b : ℝ\n⊢ a * b + a * b = 2 * a * b"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  ?m.79124 + ?m.79125 ≠ ?m.79124\na b : ℝ\n⊢ a * b + a * b = 2 * a * b"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  ?m.79165 * ?m.79166 ≠ ?m.79165\na b : ℝ\n⊢ a * b + a * b = 2 * a * b"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  ?m.79206 ≠ ?m.79206 + ?m.79207\na b : ℝ\n⊢ a * b + a * b = 2 * a * b"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  ?m.79247 ≠ ?m.79247 * ?m.79248\na b : ℝ\n⊢ a * b + a * b = 2 * a * b"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  ?m.79288 + ?m.79289 = ?m.79289\na b : ℝ\n⊢ a * b + a * b = 2 * a * b"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  ?m.79346 * ?m.79347 = ?m.79347\na b : ℝ\n⊢ a * b + a * b = 2 * a * b"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  ?m.79388 = ?m.79387 + ?m.79388\na b : ℝ\n⊢ a * b + a * b = 2 * a * b"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  ?m.79427 = ?m.79426 * ?m.79427\na b : ℝ\n⊢ a * b + a * b = 2 * a * b"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  ?m.79465 + ?m.79466 ≠ ?m.79466\na b : ℝ\n⊢ a * b + a * b = 2 * a * b"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  ?m.79504 * ?m.79505 ≠ ?m.79505\na b : ℝ\n⊢ a * b + a * b = 2 * a * b"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  ?m.79544 ≠ ?m.79543 + ?m.79544\na b : ℝ\n⊢ a * b + a * b = 2 * a * b"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  ?m.79583 ≠ ?m.79582 * ?m.79583\na b : ℝ\n⊢ a * b + a * b = 2 * a * b"}
# NEXTLINE: REPL> {"tacticState": "a b : ℝ\n⊢ a * b + a * b + ?m.79624 = 2 * a * b + ?m.79624\n\na b : ℝ\n⊢ ℝ", "sid": 23, "error": null}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "failed to synthesize instance\n  CancelCommMonoid ℝ"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  ?m.79774 ≠ ?m.79776\na b : ℝ\n⊢ a * b + a * b = 2 * a * b"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  ?m.79817 ≠ ?m.79819\na b : ℝ\n⊢ a * b + a * b = 2 * a * b"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  -?m.79862 = -?m.79863\na b : ℝ\n⊢ a * b + a * b = 2 * a * b"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  ?m.79993⁻¹ = ?m.79994⁻¹\na b : ℝ\n⊢ a * b + a * b = 2 * a * b"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  -?m.80077 = ?m.80078\na b : ℝ\n⊢ a * b + a * b = 2 * a * b"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  ?m.80142⁻¹ = ?m.80143\na b : ℝ\n⊢ a * b + a * b = 2 * a * b"}
# ...
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  (?n - 1) • ?a\na b : ℝ\n⊢ a * b + a * b = 2 * a * b"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  ?a ^ (?n - 1)\na b : ℝ\n⊢ a * b + a * b = 2 * a * b"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  (?m + ?n) • ?a\na b : ℝ\n⊢ a * b + a * b = 2 * a * b"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  ?a ^ (?m + ?n)\na b : ℝ\n⊢ a * b + a * b = 2 * a * b"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  (1 + ?n) • ?a\na b : ℝ\n⊢ a * b + a * b = 2 * a * b"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  ?a ^ (1 + ?n)\na b : ℝ\n⊢ a * b + a * b = 2 * a * b"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  ?a + ?n • ?a\na b : ℝ\n⊢ a * b + a * b = 2 * a * b"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  ?a * ?a ^ ?n\na b : ℝ\n⊢ a * b + a * b = 2 * a * b"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  ?n • ?a + ?a\na b : ℝ\n⊢ a * b + a * b = 2 * a * b"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  ?a ^ ?n * ?a\na b : ℝ\n⊢ a * b + a * b = 2 * a * b"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  (?m - ?n) • ?a\na b : ℝ\n⊢ a * b + a * b = 2 * a * b"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  ?a ^ (?m - ?n)\na b : ℝ\n⊢ a * b + a * b = 2 * a * b"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  ?m • ?a + ?n • ?a\na b : ℝ\n⊢ a * b + a * b = 2 * a * b"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  ?a ^ ?m * ?a ^ ?n\na b : ℝ\n⊢ a * b + a * b = 2 * a * b"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  ?m.99935 ^ ?m\na b : ℝ\n⊢ a * b + a * b = 2 * a * b"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  ?m.100065 ^ ?m\na b : ℝ\n⊢ a * b + a * b = 2 * a * b"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, equality or iff proof expected\n  ?m.100196 (?n • ?m.100195)\na b : ℝ\n⊢ a * b + a * b = 2 * a * b"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, equality or iff proof expected\n  ?m.100309 (?m.100308 ^ ?n)\na b : ℝ\n⊢ a * b + a * b = 2 * a * b"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, equality or iff proof expected\n  ?m.100442 (?n • ?m.100441)\na b : ℝ\n⊢ a * b + a * b = 2 * a * b"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, equality or iff proof expected\n  ?m.100555 (?m.100554 ^ ?n)\na b : ℝ\n⊢ a * b + a * b = 2 * a * b"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  ?m.100687 - ?m.100688\na b : ℝ\n⊢ a * b + a * b = 2 * a * b"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  ?m.100925 / ?m.100926\na b : ℝ\n⊢ a * b + a * b = 2 * a * b"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  ?c + ?a - (?c + ?b)\na b : ℝ\n⊢ a * b + a * b = 2 * a * b"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  ?c * ?a / (?c * ?b)\na b : ℝ\n⊢ a * b + a * b = 2 * a * b"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, pattern is a metavariable\n  ?m.101357\nfrom equation\n  ?m.101357 = ?m.101358 - ?m.101359\na b : ℝ\n⊢ a * b + a * b = 2 * a * b"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, pattern is a metavariable\n  ?m.101595\nfrom equation\n  ?m.101595 = ?m.101596 / ?m.101597\na b : ℝ\n⊢ a * b + a * b = 2 * a * b"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, pattern is a metavariable\n  ?m.101691\nfrom equation\n  ?m.101691 = ?m.101692 + ?m.101693\na b : ℝ\n⊢ a * b + a * b = 2 * a * b"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, pattern is a metavariable\n  ?m.101929\nfrom equation\n  ?m.101929 = ?m.101930 * ?m.101931\na b : ℝ\n⊢ a * b + a * b = 2 * a * b"}
# NEXTLINE: REPL> {"tacticState": "a b : ℝ\n⊢ a * b = 2 * a * b - a * b", "sid": 28, "error": null}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  ?m.102284 * ?m.102285\na b : ℝ\n⊢ a * b + a * b = 2 * a * b"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  ?a - (?a - ?b)\na b : ℝ\n⊢ a * b + a * b = 2 * a * b"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  ?a / (?a / ?b)\na b : ℝ\n⊢ a * b + a * b = 2 * a * b"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  ?a - ?b\na b : ℝ\n⊢ a * b + a * b = 2 * a * b"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  ?a / ?b\na b : ℝ\n⊢ a * b + a * b = 2 * a * b"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  ?a / (?a / ?b)\na b : ℝ\n⊢ a * b + a * b = 2 * a * b"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  ?a - ?b - ?a\na b : ℝ\n⊢ a * b + a * b = 2 * a * b"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  ?a / ?b / ?a\na b : ℝ\n⊢ a * b + a * b = 2 * a * b"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  ?m.103517 = ?m.103518 - ?m.103519\na b : ℝ\n⊢ a * b + a * b = 2 * a * b"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  ?m.103753 = ?m.103754 / ?m.103755\na b : ℝ\n⊢ a * b + a * b = 2 * a * b"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  ?m.103847 - ?m.103848 = ?m.103849\na b : ℝ\n⊢ a * b + a * b = 2 * a * b"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  ?m.104085 / ?m.104086 = ?m.104087\na b : ℝ\n⊢ a * b + a * b = 2 * a * b"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  ?a + ?b - ?a\na b : ℝ\n⊢ a * b + a * b = 2 * a * b"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  ?a * ?b / ?a\na b : ℝ\n⊢ a * b + a * b = 2 * a * b"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  ?a + (?b - ?a)\na b : ℝ\n⊢ a * b + a * b = 2 * a * b"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  ?a * (?b / ?a)\na b : ℝ\n⊢ a * b + a * b = 2 * a * b"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  ?a - (?a + ?b)\na b : ℝ\n⊢ a * b + a * b = 2 * a * b"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  ?a / (?a * ?b)\na b : ℝ\n⊢ a * b + a * b = 2 * a * b"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  ?a + (?b + -?a)\na b : ℝ\n⊢ a * b + a * b = 2 * a * b"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  ?a * (?b * ?a⁻¹)\na b : ℝ\n⊢ a * b + a * b = 2 * a * b"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  ?a + ?c + (?b - ?c)\na b : ℝ\n⊢ a * b + a * b = 2 * a * b"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  ?a * ?c * (?b / ?c)\na b : ℝ\n⊢ a * b + a * b = 2 * a * b"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  ?a - ?c + (?b + ?c)\na b : ℝ\n⊢ a * b + a * b = 2 * a * b"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  ?a / ?c * (?b * ?c)\na b : ℝ\n⊢ a * b + a * b = 2 * a * b"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  ?a - ?b + (?c - ?a)\na b : ℝ\n⊢ a * b + a * b = 2 * a * b"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  ?a / ?b * (?c / ?a)\na b : ℝ\n⊢ a * b + a * b = 2 * a * b"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  ?a + ?b - (?a - ?c)\na b : ℝ\n⊢ a * b + a * b = 2 * a * b"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  ?a * ?b / (?a / ?c)\na b : ℝ\n⊢ a * b + a * b = 2 * a * b"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  ?c - ?a - (?c - ?b)\na b : ℝ\n⊢ a * b + a * b = 2 * a * b"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  ?c / ?a / (?c / ?b)\na b : ℝ\n⊢ a * b + a * b = 2 * a * b"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  ?m.107285 - ?m.107286 = ?m.107287 - ?m.107288\na b : ℝ\n⊢ a * b + a * b = 2 * a * b"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  ?m.107524 / ?m.107525 = ?m.107526 / ?m.107527\na b : ℝ\n⊢ a * b + a * b = 2 * a * b"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  ?m.107621 - ?m.107622 = ?m.107623 - ?m.107624\na b : ℝ\n⊢ a * b + a * b = 2 * a * b"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  ?m.107860 / ?m.107861 = ?m.107862 / ?m.107863\na b : ℝ\n⊢ a * b + a * b = 2 * a * b"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, pattern is a metavariable\n  ?f ?a ?c\nfrom equation\n  ?f ?a ?c = ?f ?a ?b + ?f ?b ?c\na b : ℝ\n⊢ a * b + a * b = 2 * a * b"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, pattern is a metavariable\n  ?f ?a ?c\nfrom equation\n  ?f ?a ?c = ?f ?a ?b * ?f ?b ?c\na b : ℝ\n⊢ a * b + a * b = 2 * a * b"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, pattern is a metavariable\n  ?f ?a ?c\nfrom equation\n  ?f ?a ?c = ?f ?a ?b + ?f ?b ?c\na b : ℝ\n⊢ a * b + a * b = 2 * a * b"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, pattern is a metavariable\n  ?f ?a ?c\nfrom equation\n  ?f ?a ?c = ?f ?a ?b * ?f ?b ?c\na b : ℝ\n⊢ a * b + a * b = 2 * a * b"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  ?a / ?b * ?b\na b : ℝ\n⊢ a * b + a * b = 2 * a * b"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  ?a * ?b / ?b\na b : ℝ\n⊢ a * b + a * b = 2 * a * b"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  ?a / (?b * ?a)\na b : ℝ\n⊢ a * b + a * b = 2 * a * b"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  ?a - (?b + ?a)\na b : ℝ\n⊢ a * b + a * b = 2 * a * b"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  ?a * ?b / ?a\na b : ℝ\n⊢ a * b + a * b = 2 * a * b"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  ?a + ?b - ?a\na b : ℝ\n⊢ a * b + a * b = 2 * a * b"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  ?a * (?b / ?a)\na b : ℝ\n⊢ a * b + a * b = 2 * a * b"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  ?a + (?b - ?a)\na b : ℝ\n⊢ a * b + a * b = 2 * a * b"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  ?a / (?a * ?b)\na b : ℝ\n⊢ a * b + a * b = 2 * a * b"}
# NEXTLINE: REPL> {"tacticState": null, "sid": null, "error": "tactic 'rewrite' failed, did not find instance of the pattern in the target expression\n  ?a - (?a + ?b)\na b : ℝ\n⊢ a * b + a * b = 2 * a * b"}

# %%
for (tac, premise) in results:
    print("TAC:", tac)
    print(premise.theorem_name)
    print(premise.state.pp)
# Out:
# TAC: rw [← mul_add a b b]
# test_theorem_0
# a b : ℝ
# ⊢ a * (b + b) = 2 * a * b
# TAC: rw [two_mul]
# test_theorem_0
# a b : ℝ
# ⊢ a * b + a * b = (a + a) * b
# TAC: rw [two_mul a]
# test_theorem_0
# a b : ℝ
# ⊢ a * b + a * b = (a + a) * b
# TAC: rw [← two_mul (a * b)]
# test_theorem_0
# a b : ℝ
# ⊢ 2 * (a * b) = 2 * a * b
# TAC: rw [mul_assoc]
# test_theorem_0
# a b : ℝ
# ⊢ a * b + a * b = 2 * (a * b)
# TAC: rw [mul_assoc 2 a b]
# test_theorem_0
# a b : ℝ
# ⊢ a * b + a * b = 2 * (a * b)
# TAC: rw [add_comm]
# test_theorem_0
# a b : ℝ
# ⊢ a * b + a * b = 2 * a * b
# TAC: rw [add_comm (a * b) (a * b)]
# test_theorem_0
# a b : ℝ
# ⊢ a * b + a * b = 2 * a * b
# TAC: rw [mul_comm]
# test_theorem_0
# a b : ℝ
# ⊢ b * a + b * a = 2 * a * b
# TAC: rw [mul_comm (2 * a) b]
# test_theorem_0
# a b : ℝ
# ⊢ a * b + a * b = b * (2 * a)
# TAC: rw [mul_comm a b]
# test_theorem_0
# a b : ℝ
# ⊢ b * a + b * a = 2 * a * b
# TAC: rw [← mul_comm b a]
# test_theorem_0
# a b : ℝ
# ⊢ b * a + b * a = 2 * a * b
# TAC: rw [← add_zero a]
# test_theorem_0
# a b : ℝ
# ⊢ (a + 0) * b + (a + 0) * b = 2 * (a + 0) * b
# TAC: rw [← add_zero b]
# test_theorem_0
# a b : ℝ
# ⊢ a * (b + 0) + a * (b + 0) = 2 * a * (b + 0)
# TAC: rw [← zero_add a]
# test_theorem_0
# a b : ℝ
# ⊢ (0 + a) * b + (0 + a) * b = 2 * (0 + a) * b
# TAC: rw [← zero_add b]
# test_theorem_0
# a b : ℝ
# ⊢ a * (0 + b) + a * (0 + b) = 2 * a * (0 + b)
# TAC: rw [← mul_one a]
# test_theorem_0
# a b : ℝ
# ⊢ a * 1 * b + a * 1 * b = 2 * (a * 1) * b
# TAC: rw [← mul_one b]
# test_theorem_0
# a b : ℝ
# ⊢ a * (b * 1) + a * (b * 1) = 2 * a * (b * 1)
# TAC: rw [← one_mul b]
# test_theorem_0
# a b : ℝ
# ⊢ a * (1 * b) + a * (1 * b) = 2 * a * (1 * b)
# TAC: rw [← one_mul a]
# test_theorem_0
# a b : ℝ
# ⊢ 1 * a * b + 1 * a * b = 2 * (1 * a) * b
# TAC: rw [mul_right_comm]
# test_theorem_0
# a b : ℝ
# ⊢ a * b + a * b = 2 * b * a
# TAC: rw [mul_rotate]
# test_theorem_0
# a b : ℝ
# ⊢ a * b + a * b = a * b * 2
# TAC: rw [eq_iff_eq_of_add_eq_add]
# test_theorem_0
# a b : ℝ
# ⊢ a * b + a * b + ?m.79624 = 2 * a * b + ?m.79624
#
# a b : ℝ
# ⊢ ℝ
# TAC: rw [add_eq_of_eq_neg_add]
# test_theorem_0
# a b : ℝ
# ⊢ a * b = -(a * b) + 2 * a * b
# TAC: rw [add_eq_of_eq_add_neg]
# test_theorem_0
# a b : ℝ
# ⊢ a * b = 2 * a * b + -(a * b)
# TAC: rw [add_eq_of_eq_sub]
# test_theorem_0
# a b : ℝ
# ⊢ a * b = 2 * a * b - a * b
# TAC: rw [eq_iff_eq_of_sub_eq_sub]
# test_theorem_0
# a b : ℝ
# ⊢ a * b + a * b - 2 * a * b = ?m.95825 - ?m.95825
#
# a b : ℝ
# ⊢ ℝ
# TAC: rw [add_eq_of_eq_sub']
# test_theorem_0
# a b : ℝ
# ⊢ a * b = 2 * a * b - a * b

# %%
# Testing code for adding equivalent
equivalent = "x * x"
theorem_full_code = "theorem test_theorem_1 (a b: ℝ ) : a * b + a * b = 2 * a * b := by ring"
premise = Premise(theorem_full_code.strip())
new_theorem_name = "test_theorem_2"
ps.add_existing_premise(premise)
new_premise = ps.add_equivalent(premise, equivalent, new_theorem_name)
new_premise.to_theorem_code()
# Out:
# 2024-08-17 21:47:59.379 | INFO     | lean_dojo.interaction.dojo:_add_theorem:441 - Also copying to /tmp/tmpxin6z0w7/mathematics_in_lean/workspace/mathematics_in_lean/MIL/C02_Basics/S02_Proving_Identities_in_Algebraic_Structures.lean
# 2024-08-17 21:47:59.379 | INFO     | lean_dojo.interaction.dojo:__enter__:231 - run_interactive ...
# Adding equivalent to
# theorem test_theorem_1 (a b: ℝ) : a * b + a * b = 2 * a * b := by
#   ring
# New Premise:
# theorem test_theorem_2 (a b c: ℝ) : (a * b + a * b) * (a * b + a * b) = (2 * a * b) * (2 * a * b) := by
#   have h1: a * b + a * b = 2 * a * b := by exact test_theorem_1 a b
#   exact congrArg (λ x => x * x) h1
# Entering test_theorem_2 ...
# NEXTLINE: REPL> {"tacticState": "a b c : ℝ\n⊢ (a * b + a * b) * (a * b + a * b) = 2 * a * b * (2 * a * b)", "sid": 0, "error": null}
# NEXTLINE: REPL> {"tacticState": "a b c : ℝ\nh1 : a * b + a * b = 2 * a * b\n⊢ (a * b + a * b) * (a * b + a * b) = 2 * a * b * (2 * a * b)", "sid": 1, "error": null}
# NEXTLINE: REPL> {"tacticState": "no goals", "sid": 2, "error": null}
# 'theorem test_theorem_2 (a b c: ℝ) : (a * b + a * b) * (a * b + a * b) = (2 * a * b) * (2 * a * b) :='

# %%
# Testing code for replacement
replacement = {'a':'(c + d)'}
theorem_full_code = "theorem test_theorem_1 (a b: ℝ ) : a * b + a * b = 2 * a * b := by ring"
premise = Premise(theorem_full_code.strip())
new_theorem_name = "test_theorem_2"
#ps = PremiseSet(repo, 'MIL/C02_Basics/S02_Proving_Identities_in_Algebraic_Structures.lean', None, None)
ps.add_existing_premise(premise)
new_premise = ps.replace_variable(premise, replacement, new_theorem_name)
new_premise.to_theorem_code()
# Out:
# 2024-08-17 21:48:05.548 | INFO     | lean_dojo.interaction.dojo:_add_theorem:441 - Also copying to /tmp/tmpxin6z0w7/mathematics_in_lean/workspace/mathematics_in_lean/MIL/C02_Basics/S02_Proving_Identities_in_Algebraic_Structures.lean
# 2024-08-17 21:48:05.549 | INFO     | lean_dojo.interaction.dojo:__enter__:231 - run_interactive ...
# Replace variable to
# theorem test_theorem_1 (a b: ℝ) : a * b + a * b = 2 * a * b := by
#   ring
# New Premise:
# theorem test_theorem_2 (a b d c: ℝ) : (c + d) * b + (c + d) * b = 2 * (c + d) * b := by
#   ring
# Entering test_theorem_2 ...
# NEXTLINE: REPL> {"tacticState": "a b d c : ℝ\n⊢ (c + d) * b + (c + d) * b = 2 * (c + d) * b", "sid": 0, "error": null}
# NEXTLINE: REPL> {"tacticState": "no goals", "sid": 1, "error": null}
# 'theorem test_theorem_2 (a b d c: ℝ) : (c + d) * b + (c + d) * b = 2 * (c + d) * b :='

# %%
theorem_full_code = "theorem test_theorem_3 (a b: ℝ ) : a * b + a * b = 2 * a * b :="
new_theorem = Theorem(repo, 'MIL/C02_Basics/S02_Proving_Identities_in_Algebraic_Structures.lean', "test_theorem_3")

if ps.dojo is None:
    ps.dojo, state_0 = Dojo(new_theorem, copy_tree_on_enter=False).__enter__(
        new_theorem_code=theorem_full_code
    )
else:
    ps.dojo.entry = new_theorem
    _, state_0 = ps.dojo.__enter__(
        new_theorem_code=theorem_full_code
    )
#_, state_0 = ps.dojo.__enter__(new_theorem_code=theorem_full_code)
print(state_0)
# Out:
# 2024-07-17 23:39:16.169 | WARNING  | lean_dojo.interaction.dojo:__init__:156 - Using Lean 4 without a hard timeout may hang indefinitely.
# 2024-07-17 23:39:16.175 | INFO     | lean_dojo.interaction.dojo:__enter__:186 - Copy tree ...
# 2024-07-17 23:39:17.846 | INFO     | lean_dojo.interaction.dojo:__enter__:209 - lake build Lean4Repl ...
# 2024-07-17 23:39:17.846 | INFO     | lean_dojo.interaction.dojo:__enter__:212 - Launching the proof using <class 'lean_dojo.container.NativeContainer'>
# 2024-07-17 23:39:23.483 | INFO     | lean_dojo.interaction.dojo:__enter__:231 - run_interactive ...
# TacticState(pp='a b : ℝ\n⊢ a * b + a * b = 2 * a * b', id=0, message=None)

# %%
print(state_0.pp)
premise = Premise()
premise.parse_state(state_0.pp)


# axioms = {
#     'two_mul': (1, ['*'], ['+'])
# }

for tac_name, (num_operands, forward_operators, backward_operators) in AXIOM_METADATA.items():
    tokens = tokenize(premise.target)
    root = TargetNode.build_tree(tokens)
    #root.print_tree()
    # Forward tactic
    operands = root.get_operands(num_operands, forward_operators)
    #print("Forward operands:", operands)
    for operand in operands:
        operand_str = ' '.join(list(operand))
        tac = f"rw [{tac_name} {operand_str}]"
        next_state = ps.dojo.run_tac(state_0, tac)
        if get_state_type(next_state) < 0:
            continue
        print("TAC:", tac)
        print("STATE:", next_state.pp)
        test_state = ps.dojo.run_tac(next_state, 'simp')
        if get_state_type(test_state) >= 0:
            print("SIMP STATE:", test_state)
    # Backward tactic
    operands = root.get_operands(num_operands, backward_operators)
    #print("Backward operands:", operands)
    for operand in operands:
        operand_str = ' '.join(list(operand))
        tac = f"rw [← {tac_name} {operand_str}]"
        next_state = ps.dojo.run_tac(state_0, tac)
        if get_state_type(next_state) < 0:
            continue
        print("TAC:", tac)
        print("STATE:", next_state.pp)
        test_state = ps.dojo.run_tac(next_state, 'simp')
        if get_state_type(test_state) >= 0:
            print("SIMP STATE:", test_state)
# Out:
# a b : ℝ
# ⊢ a * b + a * b = 2 * a * b
# TAC: rw [← mul_add a b b]
# STATE: a b : ℝ
# ⊢ a * (b + b) = 2 * a * b
# TAC: rw [← add_mul a a b]
# STATE: a b : ℝ
# ⊢ (a + a) * b = 2 * a * b
# SIMP STATE: TacticState(pp='a b : ℝ\n⊢ a + a = 2 * a ∨ b = 0', id=158, message='')
# TAC: rw [two_mul a]
# STATE: a b : ℝ
# ⊢ a * b + a * b = (a + a) * b
# TAC: rw [← two_mul (a * b)]
# STATE: a b : ℝ
# ⊢ 2 * (a * b) = 2 * a * b
# TAC: rw [mul_assoc 2 a b]
# STATE: a b : ℝ
# ⊢ a * b + a * b = 2 * (a * b)
# TAC: rw [← sub_sub_cancel (2 * a * b) b]
# STATE: a b : ℝ
# ⊢ a * (2 * a * b - (2 * a * b - b)) + a * (2 * a * b - (2 * a * b - b)) = 2 * a * (2 * a * b - (2 * a * b - b))
# SIMP STATE: TacticState(pp='a b : ℝ\n⊢ a * b + a * b = 2 * a * b', id=163, message='')
# TAC: rw [← sub_sub_cancel b (a * b + a * b)]
# STATE: a b : ℝ
# ⊢ b - (b - (a * b + a * b)) = 2 * a * b
# SIMP STATE: TacticState(pp='a b : ℝ\n⊢ a * b + a * b = 2 * a * b', id=165, message='')
# TAC: rw [← sub_sub_cancel (a * b + a * b) a]
# STATE: a b : ℝ
# ⊢ (a * b + a * b - (a * b + a * b - a)) * b + (a * b + a * b - (a * b + a * b - a)) * b =
#     2 * (a * b + a * b - (a * b + a * b - a)) * b
# SIMP STATE: TacticState(pp='a b : ℝ\n⊢ a * b + a * b = 2 * a * b', id=167, message='')
# TAC: rw [← sub_sub_cancel a (a * b + a * b)]
# STATE: a b : ℝ
# ⊢ a - (a - (a * b + a * b)) = 2 * a * b
# SIMP STATE: TacticState(pp='a b : ℝ\n⊢ a * b + a * b = 2 * a * b', id=169, message='')
# TAC: rw [← sub_sub_cancel b a]
# STATE: a b : ℝ
# ⊢ (b - (b - a)) * b + (b - (b - a)) * b = 2 * (b - (b - a)) * b
# SIMP STATE: TacticState(pp='a b : ℝ\n⊢ a * b + a * b = 2 * a * b', id=171, message='')
# TAC: rw [← sub_sub_cancel a a]
# STATE: a b : ℝ
# ⊢ (a - (a - a)) * b + (a - (a - a)) * b = 2 * (a - (a - a)) * b
# SIMP STATE: TacticState(pp='a b : ℝ\n⊢ a * b + a * b = 2 * a * b', id=173, message='')
# TAC: rw [← sub_sub_cancel (a * b + a * b) b]
# STATE: a b : ℝ
# ⊢ a * (a * b + a * b - (a * b + a * b - b)) + a * (a * b + a * b - (a * b + a * b - b)) =
#     2 * a * (a * b + a * b - (a * b + a * b - b))
# SIMP STATE: TacticState(pp='a b : ℝ\n⊢ a * b + a * b = 2 * a * b', id=175, message='')
# TAC: rw [← sub_sub_cancel (a * b + a * b) (2 * a * b)]
# STATE: a b : ℝ
# ⊢ a * b + a * b = a * b + a * b - (a * b + a * b - 2 * a * b)
# SIMP STATE: TacticState(pp='a b : ℝ\n⊢ a * b + a * b = 2 * a * b', id=177, message='')
# TAC: rw [← sub_sub_cancel b (2 * a * b)]
# STATE: a b : ℝ
# ⊢ a * b + a * b = b - (b - 2 * a * b)
# SIMP STATE: TacticState(pp='a b : ℝ\n⊢ a * b + a * b = 2 * a * b', id=179, message='')
# TAC: rw [← sub_sub_cancel a (2 * a * b)]
# STATE: a b : ℝ
# ⊢ a * b + a * b = a - (a - 2 * a * b)
# SIMP STATE: TacticState(pp='a b : ℝ\n⊢ a * b + a * b = 2 * a * b', id=181, message='')
# TAC: rw [← sub_sub_cancel (2 * a * b) (a * b + a * b)]
# STATE: a b : ℝ
# ⊢ 2 * a * b - (2 * a * b - (a * b + a * b)) = 2 * a * b
# SIMP STATE: TacticState(pp='a b : ℝ\n⊢ a * b + a * b = 2 * a * b', id=183, message='')
# TAC: rw [← sub_sub_cancel b b]
# STATE: a b : ℝ
# ⊢ a * (b - (b - b)) + a * (b - (b - b)) = 2 * a * (b - (b - b))
# SIMP STATE: TacticState(pp='a b : ℝ\n⊢ a * b + a * b = 2 * a * b', id=185, message='')
# TAC: rw [← sub_sub_cancel (2 * a * b) a]
# STATE: a b : ℝ
# ⊢ (2 * a * b - (2 * a * b - a)) * b + (2 * a * b - (2 * a * b - a)) * b = 2 * (2 * a * b - (2 * a * b - a)) * b
# SIMP STATE: TacticState(pp='a b : ℝ\n⊢ a * b + a * b = 2 * a * b', id=187, message='')
# TAC: rw [← sub_sub_cancel a b]
# STATE: a b : ℝ
# ⊢ a * (a - (a - b)) + a * (a - (a - b)) = 2 * a * (a - (a - b))
# SIMP STATE: TacticState(pp='a b : ℝ\n⊢ a * b + a * b = 2 * a * b', id=189, message='')
# TAC: rw [add_comm (a * b) (a * b)]
# STATE: a b : ℝ
# ⊢ a * b + a * b = 2 * a * b
# TAC: rw [mul_comm a b]
# STATE: a b : ℝ
# ⊢ b * a + b * a = 2 * a * b
# TAC: rw [mul_comm (2 * a) b]
# STATE: a b : ℝ
# ⊢ a * b + a * b = b * (2 * a)
# TAC: rw [← mul_comm b a]
# STATE: a b : ℝ
# ⊢ b * a + b * a = 2 * a * b
# TAC: rw [← add_zero a]
# STATE: a b : ℝ
# ⊢ (a + 0) * b + (a + 0) * b = 2 * (a + 0) * b
# SIMP STATE: TacticState(pp='a b : ℝ\n⊢ a * b + a * b = 2 * a * b', id=195, message='')
# TAC: rw [← add_zero b]
# STATE: a b : ℝ
# ⊢ a * (b + 0) + a * (b + 0) = 2 * a * (b + 0)
# SIMP STATE: TacticState(pp='a b : ℝ\n⊢ a * b + a * b = 2 * a * b', id=197, message='')
# TAC: rw [← zero_add a]
# STATE: a b : ℝ
# ⊢ (0 + a) * b + (0 + a) * b = 2 * (0 + a) * b
# SIMP STATE: TacticState(pp='a b : ℝ\n⊢ a * b + a * b = 2 * a * b', id=199, message='')
# TAC: rw [← zero_add b]
# STATE: a b : ℝ
# ⊢ a * (0 + b) + a * (0 + b) = 2 * a * (0 + b)
# SIMP STATE: TacticState(pp='a b : ℝ\n⊢ a * b + a * b = 2 * a * b', id=201, message='')
# TAC: rw [← mul_one a]
# STATE: a b : ℝ
# ⊢ a * 1 * b + a * 1 * b = 2 * (a * 1) * b
# SIMP STATE: TacticState(pp='a b : ℝ\n⊢ a * b + a * b = 2 * a * b', id=203, message='')
# TAC: rw [← mul_one b]
# STATE: a b : ℝ
# ⊢ a * (b * 1) + a * (b * 1) = 2 * a * (b * 1)
# SIMP STATE: TacticState(pp='a b : ℝ\n⊢ a * b + a * b = 2 * a * b', id=205, message='')
# TAC: rw [← one_mul a]
# STATE: a b : ℝ
# ⊢ 1 * a * b + 1 * a * b = 2 * (1 * a) * b
# SIMP STATE: TacticState(pp='a b : ℝ\n⊢ a * b + a * b = 2 * a * b', id=207, message='')
# TAC: rw [← one_mul b]
# STATE: a b : ℝ
# ⊢ a * (1 * b) + a * (1 * b) = 2 * a * (1 * b)
# SIMP STATE: TacticState(pp='a b : ℝ\n⊢ a * b + a * b = 2 * a * b', id=209, message='')

# %%
print(new_premise.to_theorem_code(include_tactics=True))
# Out:
# theorem test_theorem_2 (a b c: ℝ) : c * (a * b + a * b) = c * (2 * a * b) := by
#   have h1: a * b + a * b = 2 * a * b := by exact test_theorem_1 a b
#   exact congrArg (λ x => c * x) h1

# %%
print(state_0)
print(test_state_0)
# Out:
# TacticState(pp='a b c : ℝ\n⊢ c * (a * b + a * b) = c * (2 * a * b)', id=0, message=None)
# TacticState(pp='a b c : ℝ\n⊢ c * (a * b + a * b) = c * (2 * a * b)', id=0, message=None)

# %%
new_premise.tactics
# Out:
# ['have h1: ℝ ) : a * b + a * b = 2 * a * b := by exact  ',
#  'exact congrArg (λ x => a * x) h1']

# %%
premise.target
# Out:
# 'ℝ ) : a * b + a * b = 2 * a * b'
